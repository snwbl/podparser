# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()

# %%
import requests

# %%
query = "antifragile"
url = f"http://tc02.tailc7eab.ts.net:7280/api/v1/episodes_from_stream/search?query={query}&max_hits=100&sort_by_field=%2Bpublished"
result = requests.get(url)

# %%
len("Episode 3. My opinion on Understanding Female nature.")
# Out:
# 53

# %%
result.json()
# Out:
# {'num_hits': 142,
#  'hits': [{'author': 'bigthink',
# ...

# %%
for hit in result.json()["hits"]:
    print(len(hit["title"]))
# Out:
# 40
# 50
# 46
# 48
# 49
# 42
# 46
# 50
# 46
# 45
# 50
# 47
# 45
# 45
# 20
# 38
# 46
# 46
# 20
# 36
# 46
# 19
# 19
# 46
# 23
# 42
# 31
# 43
# 17
# 49
# 43
# 30
# 38
# 47
# 44
# 43
# 36
# 49
# 43
# 44
# 19
# 45
# 32
# 28
# 42
# 48
# 49
# 46
# 30
# 20
# 46
# 36
# 44
# 26
# 23
# 27
# 50
# 44
# 48
# 48
# 42
# 21
# 11
# 49
# 35
# 46
# 45
# 49
# 48
# 49
# 46
# 45
# 48
# 28
# 22
# 35
# 49
# 44
# 39
# 50
# 40
# 45
# 48
# 39
# 49
# 49
# 50
# 47
# 23
# 39
# 39
# 30
# 39
# 39
# 49
# 49
# 24
# 21
# 48
# 11
