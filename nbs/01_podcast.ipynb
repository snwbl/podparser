# %% [markdown]
# # Podcast
#
# > Fill in a module description here

# %%
#| default_exp podcast

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()

# %%
#| export
from bs4 import BeautifulSoup
from dateutil import parser
from podparser.item import *
import lxml

# %%
import os
from rich import print

# %%
#| export
class Podcast():
    """Parses an xml rss feed

    RSS Specs http://cyber.law.harvard.edu/rss/rss.html

    More RSS Specs http://www.rssboard.org/rss-specification

    iTunes Podcast Specs http://www.apple.com/itunes/podcasts/specs.html


    The cloud element aka RSS Cloud is not supported as it has been superseded by the superior PubSubHubbub protocal

    Args:
        feed_content (str): An rss string

    Note:
        All attributes with empty or nonexistent element will have a value of None

        Attributes are generally strings or lists of strings, because we want to record the literal value of elements.

    Attributes:
        feed_content (str): The actual xml of the feed
        soup (bs4.BeautifulSoup): A soup of the xml with items and image removed
        image_soup (bs4.BeautifulSoup): soup of image
        full_soup (bs4.BeautifulSoup): A soup of the xml with items
        categories (list): List for strings representing the feed categories
        copyright (str): The feed's copyright
        creative_commons (str): The feed's creative commons license
        items (item): Item objects
        description (str): The feed's description
        generator (str): The feed's generator
        image_title (str): Feed image title
        image_url (str): Feed image url
        image_link (str): Feed image link to homepage
        image_width (str): Feed image width
        image_height (str): Feed image height
        itunes_author_name (str): The podcast's author name for iTunes
        itunes_block (bool): Does the podcast block itunes
        itunes_categories (list): List of strings of itunes categories
        itunes_complete (str): Is this podcast done and complete
        itunes_explicit (str): Is this item explicit. Should only be "yes" and "clean."
        itune_image (str): URL to itunes image
        itunes_keywords (list): List of strings of itunes keywords
        itunes_new_feed_url (str): The new url of this podcast
        language (str): Language of feed
        last_build_date (str): Last build date of this feed
        link (str): URL to homepage
        managing_editor (str): managing editor of feed
        published_date (str): Date feed was published
        pubsubhubbub (str): The URL of the pubsubhubbub service for this feed
        owner_name (str): Name of feed owner
        owner_email (str): Email of feed owner
        subtitle (str): The feed subtitle
        title (str): The feed title
        ttl (str): The time to live or number of minutes to cache feed
        web_master (str): The feed's webmaster
        is_valid_rss (bool): Is this a valid RSS Feed
        is_valid_podcast (bool): Is this a valid Podcast
        date_time (datetime): When published
    """

    def __init__(self, feed_content):
        #super(Podcast, self).__init__()
        self.feed_content = feed_content
        self.set_soup()
        self.set_full_soup()

        self.set_extended_elements()
        self.set_itunes()
        self.set_optional_elements()
        self.set_required_elements()

        self.set_validity()
        self.set_time_published()
        self.set_dates_published()

    def set_time_published(self):
        if self.published_date is None:
            self.time_published = None
            return
        self.time_published = self.published_date

    def set_dates_published(self):
        if self.published_date is None:
            self.date_time = None
        else:
            _datetime = parser.parse(self.published_date)
            self.date_time = _datetime

    def set_validity(self):
        self.set_is_valid_rss()
        self.set_is_valid_podcast()

    def set_is_valid_rss(self):
        """Check to if this is actually a valid RSS feed"""
        if self.title and self.link and self.description:
            self.is_valid_rss = True
        else:
            self.is_valid_rss = False

    def set_is_valid_podcast(self):
        for item in self.items:
            if item.enclosure_type:
                if item.enclosure_type.lower() == "audio/mpeg":
                    self.is_valid_podcast = True
                    return
        self.is_valid_podcast =  False

    def to_dict(self):
        podcast_dict = {}
        podcast_dict['categories'] = self.categories
        podcast_dict['copyright'] = self.copyright
        podcast_dict['creative_commons'] = self.creative_commons
        podcast_dict['description'] = self.description
        podcast_dict['generator'] = self.generator
        podcast_dict['image_title'] = self.image_title
        podcast_dict['image_url'] = self.image_url
        podcast_dict['image_link'] = self.image_link
        podcast_dict['image_width'] = self.image_width
        podcast_dict['image_height'] = self.image_height
        podcast_dict['items'] = []
        for item in self.items:
            item_dict = item.to_dict()
            podcast_dict['items'].append(item_dict)
        podcast_dict['itunes_author_name'] = self.itunes_author_name
        podcast_dict['itunes_block'] = self.itunes_block
        podcast_dict['itunes_categories'] = self.itunes_categories
        podcast_dict['itunes_complete'] = self.image_width
        podcast_dict['itunes_explicit'] = self.itunes_explicit
        podcast_dict['itune_image'] = self.itune_image
        podcast_dict['itunes_keywords'] = self.image_width
        podcast_dict['itunes_explicit'] = self.itunes_explicit
        podcast_dict['itunes_new_feed_url'] = self.itunes_new_feed_url
        podcast_dict['language'] = self.language
        podcast_dict['last_build_date'] = self.last_build_date
        podcast_dict['link'] = self.link
        podcast_dict['managing_editor'] = self.managing_editor
        podcast_dict['published_date'] = self.published_date
        podcast_dict['pubsubhubbub'] = self.pubsubhubbub
        podcast_dict['owner_name'] = self.owner_name
        podcast_dict['owner_email'] = self.owner_email
        podcast_dict['subtitle'] = self.subtitle
        podcast_dict['title'] = self.title
        podcast_dict['ttl'] = self.ttl
        podcast_dict['web_master'] = self.web_master
        return podcast_dict

    def set_extended_elements(self):
        """Parses and sets non required elements"""
        self.set_creative_commons()
        self.set_owner()
        self.set_subtitle()
        self.set_summary()

    def set_itunes(self):
        """Sets elements related to itunes"""
        self.set_itunes_author_name()
        self.set_itunes_block()
        self.set_itunes_complete()
        self.set_itunes_explicit()
        self.set_itune_image()
        self.set_itunes_keywords()
        self.set_itunes_new_feed_url()
        self.set_itunes_categories()
        self.set_items()

    def set_optional_elements(self):
        """Sets elements considered option by RSS spec"""
        self.set_categories()
        self.set_copyright()
        self.set_generator()
        self.set_image()
        self.set_language()
        self.set_last_build_date()
        self.set_managing_editor()
        self.set_published_date()
        self.set_pubsubhubbub()
        self.set_ttl()
        self.set_web_master()

    def set_required_elements(self):
        """Sets elements required by RSS spec"""
        self.set_title()
        self.set_link()
        self.set_description()

    def set_soup(self):
        """Sets soup and strips items"""
        self.soup = BeautifulSoup(self.feed_content, features="xml")
        for item in self.soup.findAll('item'):
            item.decompose()
        for image in self.soup.findAll('image'):
            image.decompose()

    def set_full_soup(self):
        """Sets soup and keeps items"""
        self.full_soup = BeautifulSoup(self.feed_content, features="xml")

    def set_items(self):
        self.items = []
        full_soup_items = self.full_soup.findAll('item')
        for full_soup_item in full_soup_items:
            item = Item(full_soup_item)
            if item:
                self.items.append(item)
        

    def set_categories(self):
        """Parses and set feed categories"""
        self.categories = []
        temp_categories = self.soup.findAll('category')
        for category in temp_categories:
            category_text = category.text
            self.categories.append(category_text)

    def count_items(self):
        """Counts Items in full_soup and soup. For debugging"""
        soup_items = self.soup.findAll('item')
        full_soup_items = self.full_soup.findAll('item')
        return len(soup_items), len(full_soup_items)

    def set_copyright(self):
        """Parses copyright and set value"""
        try:
            self.copyright = self.soup.find('copyright').string
        except AttributeError:
            self.copyright = None

    def set_creative_commons(self):
        """Parses creative commons for item and sets value"""
        try:
            self.creative_commons = self.soup.find(
                'creativecommons:license').string
        except AttributeError:
            self.creative_commons = None

    def set_description(self):
        """Parses description and sets value"""
        try:
            self.description = self.soup.find('description').string
        except AttributeError:
            self.description = None

    def set_generator(self):
        """Parses feed generator and sets value"""
        try:
            self.generator = self.soup.find('generator').string
        except AttributeError:
            self.generator = None

    def set_image(self):
        """Parses image element and set values"""
        temp_soup = self.full_soup
        for item in temp_soup.findAll('item'):
            item.decompose()
        image = temp_soup.find('image')
        try:
            self.image_title = image.find('title').string
        except AttributeError:
            self.image_title = None
        try:
            self.image_url = image.find('url').string
        except AttributeError:
            self.image_url = None
        try:
            self.image_link = image.find('link').string
        except AttributeError:
            self.image_link = None
        try:
            self.image_width = image.find('width').string
        except AttributeError:
            self.image_width = None
        try:
            self.image_height = image.find('height').string
        except AttributeError:
            self.image_height = None

    def set_itunes_author_name(self):
        """Parses author name from itunes tags and sets value"""
        try:
            self.itunes_author_name = self.soup.find('itunes:author').string
        except AttributeError:
            self.itunes_author_name = None

    def set_itunes_block(self):
        """Check and see if podcast is blocked from iTunes and sets value"""
        try:
            block = self.soup.find('itunes:block').string.lower()
        except AttributeError:
            block = ""
        if block == "yes":
            self.itunes_block = True
        else:
            self.itunes_block = False

    def set_itunes_categories(self):
        """Parses and set itunes categories"""
        self.itunes_categories = []
        categories = set()
        temp_categories = self.soup.findAll('itunes:category')
        for category in temp_categories:
            category_text = category.get('text')
            categories.add(category_text)
        self.itunes_categories = list(categories)

    def set_itunes_complete(self):
        """Parses complete from itunes tags and sets value"""
        try:
            self.itunes_complete = self.soup.find('itunes:complete').string
            self.itunes_complete = self.itunes_complete.lower()
        except AttributeError:
            self.itunes_complete = None

    def set_itunes_explicit(self):
        """Parses explicit from itunes tags and sets value"""
        try:
            self.itunes_explicit = self.soup.find('itunes:explicit').string
            self.itunes_explicit = self.itunes_explicit.lower()
        except AttributeError:
            self.itunes_explicit = None

    def set_itune_image(self):
        """Parses itunes images and set url as value"""
        try:
            self.itune_image = self.soup.find('itunes:image').get('href')
        except AttributeError:
            self.itune_image = None

    def set_itunes_keywords(self):
        """Parses itunes keywords and set value"""
        try:
            keywords = self.soup.find('itunes:keywords').string
        except AttributeError:
            keywords = None
        try:
            self.itunes_keywords = [keyword.strip()
                                    for keyword in keywords.split(',')]
            self.itunes_keywords = list(set(self.itunes_keywords))
        except AttributeError:
            self.itunes_keywords = []

    def set_itunes_new_feed_url(self):
        """Parses new feed url from itunes tags and sets value"""
        try:
            self.itunes_new_feed_url = self.soup.find(
                'itunes:new-feed-url').string
        except AttributeError:
            self.itunes_new_feed_url = None

    def set_language(self):
        """Parses feed language and set value"""
        try:
            self.language = self.soup.find('language').string
        except AttributeError:
            self.language = None

    def set_last_build_date(self):
        """Parses last build date and set value"""
        #try:
        #    self.last_build_date = self.soup.find('lastbuilddate').string
        #except AttributeError:
        #    self.last_build_date = None
        self.last_build_date = self.soup.find('lastbuilddate')
        if not self.last_build_date:
            self.last_build_date = self.soup.find('lastBuildDate')
        if self.last_build_date:
            self.last_build_date = self.last_build_date.text

    def set_link(self):
        """Parses link to homepage and set value"""
        try:
            self.link = self.soup.find('link').string
        except AttributeError:
            self.link = None

    def set_managing_editor(self):
        """Parses managing editor and set value"""
        try:
            self.managing_editor = self.soup.find('managingeditor').string
        except AttributeError:
            self.managing_editor = None

    def set_published_date(self):
        """Parses published date and set value"""
        self.published_date = self.soup.find('pubDate')
        if not self.published_date:
            self.published_date = self.soup.find('pubdate')
        if self.published_date:
            self.published_date = self.published_date.text
            
    def set_pubsubhubbub(self):
        """Parses pubsubhubbub and email then sets value"""
        self.pubsubhubbub = None
        atom_links = self.soup.findAll('atom:link')
        for atom_link in atom_links:
            rel = atom_link.get('rel')
            if rel == "hub":
                self.pubsubhubbub = atom_link.get('href')

    def set_owner(self):
        """Parses owner name and email then sets value"""
        owner = self.soup.find('itunes:owner')
        try:
            self.owner_name = owner.find('itunes:name').string
        except AttributeError:
            self.owner_name = None
        try:
            self.owner_email = owner.find('itunes:email').string
        except AttributeError:
            self.owner_email = None

    def set_subtitle(self):
        """Parses subtitle and sets value"""
        try:
            self.subtitle = self.soup.find('itunes:subtitle').string
        except AttributeError:
            self.subtitle = None

    def set_summary(self):
        """Parses summary and set value"""
        try:
            self.summary = self.soup.find('itunes:summary').string
        except AttributeError:
            self.summary = None

    def set_title(self):
        """Parses title and set value"""
        try:
            self.title = self.soup.title.string
        except AttributeError:
            self.title = None

    def set_ttl(self):
        """Parses summary and set value"""
        try:
            self.ttl = self.soup.find('ttl').string
        except AttributeError:
            self.ttl = None

    def set_web_master(self):
        """Parses the feed's webmaster and sets value"""
        try:
            self.web_master = self.soup.find('webmaster').string
        except AttributeError:
            self.web_master = None

# %% [markdown]
# ## Pydantic

# %%
#| export
from pydantic import BaseModel
from pydantic import field_validator
from datetime import datetime
from typing import List, Optional, Union
import justext
import re
import xmltodict

# %%
#| export
class PodcastMetadata(BaseModel):
    #categories: Optional[List[str]] = []
    feed_id: Optional[str] = None
    copyright: Optional[str] = None
    creative_commons: Optional[str] = None
    description: Optional[str] = None
    generator: Optional[str] = None
    image_title: Optional[str] = None
    image_url: Optional[str] = None
    image_link: Optional[str] = None
    items: List[Episode] = []
    itunes_id: Optional[str] = None
    itunes_author_name: Optional[str] = None
    itunes_block: Optional[bool] = None
    itunes_categories: Optional[List] = None
    itunes_complete: Optional[str] = None
    itunes_explicit: Optional[bool] = None
    itune_image: Optional[str] = None
    itunes_keywords: Optional[str] = None
    itunes_explicit: Optional[bool] = None
    itunes_new_feed_url: Optional[str] = None
    language: Optional[str] = None
    last_build_date: Optional[datetime] = None
    link: Optional[str] = None
    managing_editor: Optional[str] = None
    published_date: Optional[datetime] = None
    pubsubhubbub: Optional[str] = None
    owner_name: Optional[str] = None
    owner_email: Optional[str] = None
    subtitle: Optional[str] = None
    title: Optional[str] = None
    ttl: Optional[str] = None
    web_master: Optional[str] = None
    feed_url: Optional[str] = None
    detected_language: Optional[str] = None
    
   
    @field_validator("description", mode="before")
    @classmethod
    def clean_text(cls, text):
        try:
            paragraphs = justext.justext(text, justext.get_stoplist("English"))
        except ValueError:
            return text
        except lxml.etree.ParserError:
            return text
        except TypeError:
            return text
        _text = ""
        for paragraph in paragraphs:
            _text += f"{paragraph.text} "
        return _text.strip()


    @field_validator(*['published_date', 'last_build_date'], mode='before')
    @classmethod
    def parse_date(cls, published_date):
        if published_date:
            published_date = parser.parse(published_date)
            return published_date.isoformat()
        else:
            return published_date


    @field_validator('itunes_explicit', mode='before')
    @classmethod
    def parse_itunes_explicit(cls, itunes_explicit):
        if itunes_explicit == "clean":
            return False
        else:
            return itunes_explicit

# %%
nbdev.nbdev_export()

# %%
_transcripts = []
directory = '../data'
for filename in os.listdir(directory):
    file = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(file):
        #with open(file, "r") as f:
        #    podcast = Podcast(f.read())
        #    _podcast = podcast.to_dict()
        #    del _podcast["items"]
        #    print(_podcast)
        with open(file, "r") as f:
            soup = BeautifulSoup(f, features="xml")
            for item in soup.find_all("item"):
                transcripts = item.find_all("transcript")
                if transcripts:
                    for transcript in transcripts:
                        _transcripts.append(
                            {
                                "type": transcript["type"],
                                "url": transcript["url"],
                            }
                        )

# %%
with open(file, "r") as f:
    soup = BeautifulSoup(f, features="xml")

# %%
import xmltodict

# %%
feeds = []
podcasts = []
directory = '../data'
for filename in os.listdir(directory):
    file = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(file):
        with open(file, "r") as f:
            feeds.append(f.read())
        with open(file, "r") as f:
            podcasts.append(Podcast(f.read()))

# %%
podcasts[4].to_dict()["categories"]
podcasts[4].to_dict()["podcast_transcripts"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 podcasts[4].to_dict()["categories"]
# ----> 2 podcasts[4].to_dict()["podcast_transcripts"]
#
# KeyError: 'podcast_transcripts'

# %%
soup = BeautifulSoup(feeds[1], features="xml")

# %%
p = PodcastMetadata(**podcasts[3].to_dict())
p.dict()
# Out:
# {'feed_id': None,
#  'copyright': '2024 Wolfgang Wee',
#  'creative_commons': None,
#  'description': 'Wolfgang Wee Uncut | Lange, uredigerte samtaler om kultur, politikk, samfunn, vitenskap, idrett, trening, kosthold, psykologi og mye mer, med spennende gjester. Gå hit for: WWU på Spotify for Abonnenter Støtt Wolfgang Wee Uncut: Vipps-nummer: #759273 Paypal Kryptovaluta (Bitcoin, Ethereum +++) Eller bli abonnent og få tilgang til eksklusive episoder og serier: Spotify Youtube Apple Podcast For annonsering og samarbeid, kontakt Moderne Media: info@modernemedia.no eller wolfgangweemailinglist@gmail.com.',
#  'generator': None,
#  'image_title': None,
#  'image_url': None,
#  'image_link': None,
#  'items': [{'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/ca357c93-884b-4eaf-a600-b21f011a734d/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 150260791,
#    'guid': 'ca357c93-884b-4eaf-a600-b21f011a734d',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 9388,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/ca357c93-884b-4eaf-a600-b21f011a734d/image.jpg?t=1730826643&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '567',
#    'description': 'Wolfgang Wee Uncut #567: Kjell Erik Eilertsen er energipolitisk talsperson i Industri- og næringspartiet. Han er utdannet sivilingeniør i petroleumsteknologi og økonomi og har tidligere jobbet i oljebransjen og meglerbransjen. Han har også jobbet som journalist i Finansavisen. 0:00 Start 3:38 Smør 5:11 Giftige planteoljer 10:00 Strømpolitikk 12:42 Vanvittig høye strømpriser 15:00 Moms 22:14 Utenlandskablene 25:23 Politikerne har ikke peiling 2 26:34 Vindkraftlobbyen 30:00 Klimapolitikk 33:02 Norsk gass 34:24 Umulige mål 36:00 Partiene 39:10 Hybridkabler 43:50 De er like gale 45:00 ACER 47:00 Stortinget 50:31 ACER vs. grunnloven 51:32 Fraværsgrense for politikere 52:15 Udemokratisk stortingsvalg 56:00 Signatursystemet 59:20 Stemmekveg 1:05:00 Oljeboka 1:13:30 Klimahysteri 1:16:13 Klimatull 1:22:00 Forurensning og miljøvern 1:23:07 Økonomisk selvmord 1:29:10 Nettleie 1:35:50 Vindkraft øker nettleien 1:37:30 Infrastruktur 1:44:23 Uten vindkraft 1:46:00 Kjernekraft 1:48:08 Klimapolitisk sløseri 1:54:00 Fornybar Norge 2:03:00 Kansellert av NRK? 2:06:12 Aktiv Næringspolitikk 2:15:00 Skatter og avgifter 2:16:52 Formuesskatten må bort 2:19:27 Absurd forskuddsskatt 2:22:00 Kronekursen 2:29:51 Ingen forandring 2:34:00 Bokanbefalinger See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/kjell-erik-eilertsen-klimapolitisk-sl-seri-vindkra',
#    'published_date': datetime.datetime(2024, 11, 18, 2, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Kjell Erik Eilertsen | Klimapolitisk Sløseri, Skjult Beskatning, Vindkraft Øker Nettleien, Hybridkabler, Aktiv Næringspolitikk, Umulige Klimamål, ACER, Fornybar Norge, Formuesskatten, Strømprisene',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/1052ebf9-ccd6-4944-9cb9-b2220154911a/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 100304260,
#    'guid': '1052ebf9-ccd6-4944-9cb9-b2220154911a',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 6265,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/1052ebf9-ccd6-4944-9cb9-b2220154911a/image.jpg?t=1731098558&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '560',
#    'description': 'Wolfgang Wee Uncut #560: Dag O. Hessen er biolog og professor ved Universitetet i Oslo, og nå aktuell med boken "Å Tenke Med Zappfe". Han er mest kjent for sin forskning innen vann, økologi og evolusjon, samt sitt engasjement i krysningsfeltet mellom biologi, miljø og filosofi. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/ep-hessen-zapffe',
#    'published_date': datetime.datetime(2024, 11, 14, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Dag O. Hessen | Mennesket og Naturen, Hvordan Fylle Livet Med Mening, Høyverdig Fritid, Filosofen Zappfe,\xa0Døden og Nihilisme, Forbrukssamfunnet,\xa0Eksistensialisme',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/2ab55eac-1255-4c5b-b38c-b21f01218b10/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 100579100,
#    'guid': '2ab55eac-1255-4c5b-b38c-b21f01218b10',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 6283,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/2ab55eac-1255-4c5b-b38c-b21f01218b10/image.jpg?t=1730828103&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '562',
#    'description': 'Wolfgang Wee Uncut #562: Mette Kalager er lege og professor, og tilsatt ved Oslo Universitetssykehus og Universitetet i Oslo. Hun har blant annet forsket på mammografiprogrammet og konkludert med at fordelene man får ut av dette ikke forsvarer de negative konsekvensene grunnet overbehandling. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/mette-kalager-kreft-og-overdiagnostisering-screeni',
#    'published_date': datetime.datetime(2024, 11, 12, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Mette Kalager | Kreft og Overdiagnostisering, Screening, Frykt, Medikalisering, Biomakt, Helsebusiness, Selvmonitorering',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/ed8aa9ce-2949-40bc-b7e8-b21f012166fb/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 84023587,
#    'guid': 'ed8aa9ce-2949-40bc-b7e8-b21f012166fb',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 5248,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/ed8aa9ce-2949-40bc-b7e8-b21f012166fb/image.jpg?t=1730828117&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '561',
#    'description': 'Wolfgang Wee Uncut #561: Mette Kalager er lege og professor, og tilsatt ved Oslo Universitetssykehus og Universitetet i Oslo. Hun har blant annet forsket på mammografiprogrammet og konkludert med at fordelene man får ut av dette ikke forsvarer de negative konsekvensene grunnet overbehandling. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/mette-kalager-systemsvikt-og-flukt-i-helsevesenet',
#    'published_date': datetime.datetime(2024, 11, 11, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Mette Kalager | Systemsvikt og Flukt i Helsevesenet, Ble Ubrent, Helsekøene, Kostrådene, Saltvannsbad, Svettelukt, Sminke',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/a26db37c-8734-4136-aa2f-b21b011e8795/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 162022773,
#    'guid': 'a26db37c-8734-4136-aa2f-b21b011e8795',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 10123,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/a26db37c-8734-4136-aa2f-b21b011e8795/image.jpg?t=1730481835&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '563',
#    'description': 'Wolfgang Wee Uncut #563: Bjørn Ekeberg er filosof og CEO i Recharge Health. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/bj-rn-ekeberg-infrar-d-terapi-r-dlys-og-mitokondri',
#    'published_date': datetime.datetime(2024, 11, 7, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Bjørn Ekeberg | Infrarød Terapi, Kosmologi, Rødlys og Mitokondrier, Bigbang, Universet, Flexbeam',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/75f3fa11-e4ef-4582-bae8-b21601450cc2/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 127687022,
#    'guid': '75f3fa11-e4ef-4582-bae8-b21601450cc2',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 7977,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/75f3fa11-e4ef-4582-bae8-b21601450cc2/image.jpg?t=1730058239&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '559',
#    'description': 'Wolfgang Wee Uncut #559: Saher Sourouri er psykolog og aktivist i Arkitekturopprøret. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/saher-sourouri-arkitekturoppr-ret-modernisme-obos',
#    'published_date': datetime.datetime(2024, 11, 4, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Saher Sourouri | Arkitekturopprøret,\xa0Modernisme, OBOS-ørken, Ideologi, Norske Arkitekter, Ny-urbanisme, Nasjonalmuseet, Barcode, Operaen, Snøhetta',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/4ae2d169-7610-4cc3-8cc8-b2160147536d/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 157917852,
#    'guid': '4ae2d169-7610-4cc3-8cc8-b2160147536d',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 9866,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/4ae2d169-7610-4cc3-8cc8-b2160147536d/image.jpg?t=1730058900&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '556',
#    'description': 'Wolfgang Wee Uncut #556: Øystein Sjølie er forfatter, samfunnsøkonom og lektor i økonomi ved Høgskolen i Innlandet. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/ystein-sj-lie-hvor-farlig-er-egentlig-klimaendring',
#    'published_date': datetime.datetime(2024, 10, 31, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Øystein Sjølie | Hvor Farlig Er Egentlig Klimaendringene? Norsk Olje, Paris-avtalen, FNs Klimapanel, Klimatrusler, Klimamål,\xa0Dommedagsscenarioer,\xa0Bærekraft',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/49c938b6-3c57-4f03-92d0-b210013268de/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 164974054,
#    'guid': '49c938b6-3c57-4f03-92d0-b210013268de',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 10307,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/49c938b6-3c57-4f03-92d0-b210013268de/image.jpg?t=1729535872&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '558',
#    'description': 'Wolfgang Wee Uncut #558: Marstein er rapper fra Gamlebyen og Tøyen i Oslo, og kjent fra gruppen Undergrunn. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/marstein-undergrunn-mystikk-eksponering-ungdomsstr',
#    'published_date': datetime.datetime(2024, 10, 29, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Marstein | Undergrunn, Livet Som Artist, Mystikk, Dating, Kroppsidealer, Ungdomsstress, Markedsføring, Soloprosjekter, Karrieren, Kunstig Intelligens, 2004 vs 2024, Karrieren',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/43ef7445-6e23-4f1f-a3ec-b1ee013ffd00/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 42381400,
#    'guid': '43ef7445-6e23-4f1f-a3ec-b1ee013ffd00',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 2646,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/43ef7445-6e23-4f1f-a3ec-b1ee013ffd00/image.jpg?t=1726601227&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '549',
#    'description': 'Wolfgang Wee Uncut #549: Terje Tvedt er professor, forfatter og dokumentarfilmskaper. Norske Tenkemåter Miniserie Episode 1: Pandemien Episode 2: Et Norge i Krig Episode 3: Vann og Strøm Episode 4: Menneskerettighetene og Islam Kjøp boken "Norske Tenkemåter" her: https://bok.norli.no/norske-tenkemaater See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/terje-tvedt-norges-handlingsplan-mot-muslimhat-abi',
#    'published_date': datetime.datetime(2024, 10, 28, 2, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Terje Tvedt | Islam, Muslimhat i Norge, Abid Raja, Menneskerettighetene, Islam,',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/9297bf12-1b75-4d72-81ff-b1f80111512b/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 231308203,
#    'guid': '9297bf12-1b75-4d72-81ff-b1f80111512b',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 14453,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/9297bf12-1b75-4d72-81ff-b1f80111512b/image.jpg?t=1727455002&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '551',
#    'description': 'Wolfgang Wee Uncut #551: Andre Mundal er tidligere offiser og diplomat, og aktuell med boken "De Flinkeste Slutter". See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/andre-mundal-det-norske-byr-kratiet-de-flinkeste-s',
#    'published_date': datetime.datetime(2024, 10, 23, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Andre Mundal | Det\xa0Norske Byråkratiet,\xa0På Innsiden av Utenriksdepartementet, De Flinkeste Slutter, Systemparadokset',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/0c61c673-825b-4677-9a2b-b20b008b5123/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 71845353,
#    'guid': '0c61c673-825b-4677-9a2b-b20b008b5123',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 4487,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/0c61c673-825b-4677-9a2b-b20b008b5123/image.jpg?t=1729068256&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '557',
#    'description': 'Wolfgang Wee #557: Trygve Slagsvold Vedum er en norsk gårdbruker og politiker (Sp) som er Norges finansminister siden oktober 2021. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/finansminister-vedum-det-norske-skattetrykket-stat',
#    'published_date': datetime.datetime(2024, 10, 21, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Finansminister Vedum | Det Norske Skattetrykket, Staten Vokser, Exit-skatten, Sveits og Skatteflyktninger,  Formuesskatt, Rekordstort Statsbudsjett, Byråkratiet',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/83dd06e8-361b-4167-9110-b20b0069d44c/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 155875644,
#    'guid': '83dd06e8-361b-4167-9110-b20b0069d44c',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 9738,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/83dd06e8-361b-4167-9110-b20b0069d44c/image.jpg?t=1729061957&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '555',
#    'description': 'Wolfgang Wee Uncut #555: Cecilie Hellestveit er jurist, folkerettsekspert, konfliktforsker og utenrikspolitisk kommentator. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/cecilie-hellestveit-situasjonen-i-midt-sten-israel',
#    'published_date': datetime.datetime(2024, 10, 16, 7, 2, 20, tzinfo=TzInfo(UTC)),
#    'title': 'Cecilie Hellestveit | Midtøsten Spesial: Israel vs Libanon, Iran, Hizbollah, Hamas, Gaza, Palestina, Russland, Syria, Folkeretten, Folkemord',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/60afa638-1916-46a1-8d6b-b1ee013ffd07/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 87280120,
#    'guid': '60afa638-1916-46a1-8d6b-b1ee013ffd07',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 5450,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/60afa638-1916-46a1-8d6b-b1ee013ffd07/image.jpg?t=1726601198&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '548',
#    'description': 'Wolfgang Wee Uncut #548: Terje Tvedt er professor, forfatter og dokumentarfilmskaper. Norske Tenkemåter Miniserie Episode 1: Pandemien Episode 2: Et Norge i Krig Episode 3: Vann og Strøm Episode 4: Menneskerettighetene og Islam Kjøp boken "Norske Tenkemåter" her: https://bok.norli.no/norske-tenkemaater See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/terje-tvedt-norsk-energipolitikk-utenlandskablene',
#    'published_date': datetime.datetime(2024, 10, 14, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Terje Tvedt | Norsk Energipolitikk, Utenlandskablene, Strømprisene, Det Grønne Skiftet, Statnett',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/d737532e-0ceb-449e-82de-b1f80111c84d/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 173299274,
#    'guid': 'd737532e-0ceb-449e-82de-b1f80111c84d',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 10828,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/d737532e-0ceb-449e-82de-b1f80111c84d/image.jpg?t=1727455239&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '552',
#    'description': 'Wolfgang Wee Uncut #552: Wolfgang Wee Uncut #425: Mads Larsen er forsker og forfatter. Last ned "Stories of Love from Vikings to Tinder" gratis her: https://www.taylorfrancis.com/books/oa-mono/10.4324/9781003499237/stories-love-vikings-tinder-mads-larsen Mads Larsen foredrag: https://talerlisten.no/profil/mads-larsen/ See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/mads-larsen-ai-kj-rlighet-hvorfor-kvinner-styrer-d',
#    'published_date': datetime.datetime(2024, 10, 9, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Mads Larsen |\xa0AI, Kjærlighet, Hvorfor Kvinner Styrer Datingmarkedet, Fødselsrater og Sivilisasjonens Kollaps,\xa0Robotelskere,\xa0Hypergami, Bodycount',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/bbae0f09-27aa-4d45-bac8-b1f80111d1c6/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 81239563,
#    'guid': 'bbae0f09-27aa-4d45-bac8-b1f80111d1c6',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 5074,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/bbae0f09-27aa-4d45-bac8-b1f80111d1c6/image.jpg?t=1727467020&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '554',
#    'description': 'Wolfgang Wee Uncut #554: Peter Warren er investor, podcaster og tidligere elitesoldat. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/peter-warren-norsk-finanspolitikk-svake-kronen-kap',
#    'published_date': datetime.datetime(2024, 10, 7, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Peter Warren | Norsk Finanspolitikk: Svake Kronen, Kapitalflukt, Skatt, Offentlig Sløsing, Renta, Sveits og Skatteflyktningene, Oljefondet, Laffer-effekten, Innovasjon, Valget 2025, Ernas Valgflesk',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/becbffaf-6253-4fc8-9ef3-b18d00bbe44c/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 50993442,
#    'guid': 'becbffaf-6253-4fc8-9ef3-b18d00bbe44c',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3183,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/becbffaf-6253-4fc8-9ef3-b18d00bbe44c/image.jpg?t=1720353131&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '529',
#    'description': 'WWU Presenterer: Filosofi med Einar Øverenget - Sesong 3: De Store -ismene. Einar Øverenget er filosof, forfatter og foredragsholder. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/einar-verenget-filosofi-s3e07-nihilisme-rasjonalis',
#    'published_date': datetime.datetime(2024, 10, 4, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Einar Øverenget | Filosofi S3E07 | Nihilisme, Rasjonalisme, Realisme, Epikureisme, Utilitarisme',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/c483b2fb-4b8f-4f1e-b466-b1f80111d1bf/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 107981749,
#    'guid': 'c483b2fb-4b8f-4f1e-b466-b1f80111d1bf',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 6745,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/c483b2fb-4b8f-4f1e-b466-b1f80111d1bf/image.jpg?t=1727466878&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '553',
#    'description': 'Wolfgang Wee Uncut #553: Peter Warren er investor og tidligere elitesoldat. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/peter-warren-panikk-vs-rolig-i-krisesituasjoner-kr',
#    'published_date': datetime.datetime(2024, 10, 2, 1, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Peter Warren | Panikk vs Ro i Krisesituasjoner, Krigen i Ukraina, Farlig Oppdrag, Utstyrskrise, Putins Planer, Tredje Verdenskrig, Dødstall, Midtøsten',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/d72d0fcc-65d3-432d-b5af-b1ea010e8071/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 58332546,
#    'guid': 'd72d0fcc-65d3-432d-b5af-b1ea010e8071',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3642,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/d72d0fcc-65d3-432d-b5af-b1ea010e8071/image.jpg?t=1726246184&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '547',
#    'description': 'Wolfgang Wee Uncut #547: Terje Tvedt er professor, forfatter og dokumentarfilmskaper. Kjøp boken "Norske Tenkemåter" her: https://bok.norli.no/norske-tenkemaater Norske Tenkemåter Miniserie Episode 1: Pandemien Episode 2: Et Norge i Krig Episode 3: Vann og strøm Episode 4: Ytringsfrihet See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/terje-tvedt-et-norge-i-krig-libya-og-afghanistan-f',
#    'published_date': datetime.datetime(2024, 9, 30, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Terje Tvedt | Et Norge i Krig: Libya og Afghanistan | Fiasko, Taliban, Bombing, Oppvask, Jens Stoltenberg',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/c4e0aa9a-7f48-414d-babd-b18d00bbe499/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 46737801,
#    'guid': 'c4e0aa9a-7f48-414d-babd-b18d00bbe499',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 2917,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/c4e0aa9a-7f48-414d-babd-b18d00bbe499/image.jpg?t=1720352413&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '528',
#    'description': 'WWU Presenterer: Filosofi med Einar Øverenget - Sesong 3: De Store -ismene. Einar Øverenget er filosof, forfatter og foredragsholder. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/einar-verenget-filosofi-s3e06-eksistensialisme-fin',
#    'published_date': datetime.datetime(2024, 9, 27, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Einar Øverenget | Filosofi S3E06 | EKSISTENSIALISME | Finne Meningen Med Livet, Angst vs Frykt, Valg og Dilemmaer, Søren Kierkegaard',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/afb53600-51b5-4df4-8da3-b1f0011fcf87/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 116315430,
#    'guid': 'afb53600-51b5-4df4-8da3-b1f0011fcf87',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 7265,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/afb53600-51b5-4df4-8da3-b1f0011fcf87/image.jpg?t=1726771626&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '550',
#    'description': 'Wolfgang Wee Uncut #550: Edmond Yang er AI-ekspert, billedkunstner, gründer og foredragsholder. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/edmond-yang-ai-chatgpt-bildegenerering-kappl-pet-m',
#    'published_date': datetime.datetime(2024, 9, 26, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Edmond Yang\xa0|\xa0AI: ChatGPT,\xa0Bildegenerering, Kappløpet,\xa0Markedsføring, Produktdesign, Falske Videor, Videomodeller,\xa0Weirdcore, Etterretning, Regulering',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/35a03d9e-93c1-413a-bde6-b1d9010bdc25/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 64426778,
#    'guid': '35a03d9e-93c1-413a-bde6-b1d9010bdc25',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 4023,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/35a03d9e-93c1-413a-bde6-b1d9010bdc25/image.jpg?t=1724775429&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '542',
#    'description': 'Wolfgang Wee Uncut presenterer Psykologi med Lars Dehli - Sesong 2 | Lars Dehli er klinisk psykolog og spesialist i kognitiv terapi. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/lars-dehli-s02e11-sosial-fobi-symptomer-angst-yeko',
#    'published_date': datetime.datetime(2024, 9, 23, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Lars Dehli S02E11 | Sosial Fobi | Symptomer, Angst, Øyekontakt, Introvert, Sjenert, Eksponeringsterapi',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/3bc6f2c4-1567-4e97-8b82-b18d00bbe3c5/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 58596357,
#    'guid': '3bc6f2c4-1567-4e97-8b82-b18d00bbe3c5',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3658,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/3bc6f2c4-1567-4e97-8b82-b18d00bbe3c5/image.jpg?t=1720351128&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '527',
#    'description': 'WWU Presenterer: Filosofi med Einar Øverenget - Sesong 3: De Store -ismene. Einar Øverenget er filosof, forfatter og foredragsholder. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/einar-verenget-filosofi-s3e05-materialisme-bevisst',
#    'published_date': datetime.datetime(2024, 9, 21, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Einar Øverenget | Filosofi S3E05 | MATERIALISME | Bevissthet, Marx, Atomistene, Determinisme',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/46d676ff-88fe-4f5b-b58e-b1ea010e8123/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 87945473,
#    'guid': '46d676ff-88fe-4f5b-b58e-b1ea010e8123',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 5493,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/46d676ff-88fe-4f5b-b58e-b1ea010e8123/image.jpg?t=1726244720&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '546',
#    'description': 'Wolfgang Wee Uncut #546: Terje Tvedt er professor, forfatter og dokumentarfilmskaper. Kjøp boken "Norske Tenkemåter" her: https://bok.norli.no/norske-tenkemaater Norske Tenkemåter Miniserie Episode 1: Pandemien Episode 2: Et Norge i Krig Episode 3: Vann og strøm Episode 4: Ytringsfrihet See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/terje-tvedt-hva-skjedde-med-norge-under-pandemien',
#    'published_date': datetime.datetime(2024, 9, 18, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Terje Tvedt | Hva Skjedde Med Norge Under Pandemien? | Koronakommisjonen, Hemmelighold, WHO, Heksejakt På De Uvaksinerte, Intensivplassene,\xa0Gulvog og Nakstad, Helsedirektoratet,\xa0 Smittervernsloven',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/3a48d761-f829-4556-ac5c-b1e1010a3930/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 184781580,
#    'guid': '3a48d761-f829-4556-ac5c-b1e1010a3930',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 11545,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/3a48d761-f829-4556-ac5c-b1e1010a3930/image.jpg?t=1725466192&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '545',
#    'description': 'Wolfgang Wee Uncut #545: Marit Kolby er ernæringsbiolog, forfatter, og høyskolelektor ved Oslo Nye Høyskole. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/marit-kolby-den-nye-kostr-dene-dagligvareskandalen',
#    'published_date': datetime.datetime(2024, 9, 16, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Marit Kolby |\xa0Den Nye Kostrådene, Dagligvareskandalen, Fettskrekk, Kjøttgrense, Ultraprosessert Mat, Hjemmebakt Brød, Lettbrus, Miljøgifter i Sjømat, Matindustrien, Helsedirektoratet',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/4a5f8f37-e506-4cf5-8843-b18d00bbe44d/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 50230786,
#    'guid': '4a5f8f37-e506-4cf5-8843-b18d00bbe44d',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3136,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/4a5f8f37-e506-4cf5-8843-b18d00bbe44d/image.jpg?t=1719000378&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '526',
#    'description': 'WWU Presenterer: Filosofi med Einar Øverenget - Sesong 3: De Store -ismene. Einar Øverenget er filosof, forfatter og foredragsholder. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/einar-verenget-filosofi-s3e04-idealisme-immanuel-k',
#    'published_date': datetime.datetime(2024, 9, 13, 0, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Einar Øverenget | Filosofi S3E04 | IDEALISME | Immanuel Kant, Trancendental, Fenomenologi, Descartes',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/e453e290-a484-4a32-9e72-b1dc012eb5bf/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 137094139,
#    'guid': 'e453e290-a484-4a32-9e72-b1dc012eb5bf',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 8565,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/e453e290-a484-4a32-9e72-b1dc012eb5bf/image.jpg?t=1725284563&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '544',
#    'description': 'Wolfgang Wee Uncut #544: Gaute Grøtta Grav er leder for informasjon og kommunikasjon i Motvind Norge, samt musiker, programleder, realitydeltaker og lokalpolitiker i Høyre. See omnystudio.com/listener for privacy information.',
#    'link': 'https://omny.fm/shows/wolfgang-wee-uncut/gaute-gr-tta-grav-kampen-mot-vindkraft-rasering-av',
# ...
#    'itunes_episode': '7',
#    'description': 'Mathias Nylenna er programleder og journalist i NRK Radio. Han jobber for tiden som programleder i Her og Nå på NRK P1, etter å ha ledet andre radioprogrammer som Verdibørsen på P2 og Verdens Rikeste Land på P3. Hør Wolfgang Wee Uncut i Spotify Hør Wolfgang Wee Uncut i Apple Podcast Se Wolfgang Wee Uncut på Youtube Ukentlig Nyhetsbrev (påmelding her) Wolfgang Wee Uncut Hjemmeside Instagram Facebook Twitter For podcast tips, podcast anbefalinger, podtoppen, podcast toppen, podkast og en oversikt over alle episodene med Wolfgang Wee Uncut, besøk https://www.pod-cast.no See acast.com/privacy for privacy and opt-out information. See omnystudio.com/listener for privacy information.',
#    'link': 'https://pod.space/wolfgangweeuncut/mathias-nylenna-om-politikk-livet-i-nrk-verdens-rikest-land-her-og-na-og-hans-zimmer',
#    'published_date': datetime.datetime(2019, 5, 12, 2, 50, 25, tzinfo=TzInfo(UTC)),
#    'title': 'Mathias Nylenna: om politikk, livet i NRK, Verdens Rikest Land, Her og Nå, og Hans Zimmer',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/b3938889-0aa3-40ca-9729-b14901520c9f/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 126237189,
#    'guid': '6cf26a59-c17d-4b41-a9b1-3c0d122d333e',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 7885,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/b3938889-0aa3-40ca-9729-b14901520c9f/image.jpg?t=1712349056&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': 'Aslak Klever er grunnlegger og CEO i Popular By Demand Management. Han har tidligere jobbet for Universal Music og Emi Music, rappet med Warlocks og Son of Light, og sluttet å drikke.',
#    'itunes_episode': '6',
#    'description': 'Aslak Klever er grunnlegger og CEO i Popular By Demand Management. Han har tidligere jobbet for Universal Music og Emi Music, rappet med Warlocks og Son of Light, og sluttet å drikke. Hør Wolfgang Wee Uncut i Spotify Hør Wolfgang Wee Uncut i Apple Podcast Se Wolfgang Wee Uncut på Youtube Ukentlig Nyhetsbrev (påmelding her) Wolfgang Wee Uncut Hjemmeside Instagram Facebook Twitter For podcast tips, podcast anbefalinger, podtoppen, podcast toppen, podkast og en oversikt over alle episodene med Wolfgang Wee Uncut, besøk https://www.pod-cast.no See acast.com/privacy for privacy and opt-out information. See omnystudio.com/listener for privacy information.',
#    'link': 'https://pod.space/wolfgangweeuncut/aslak-klever-om-musikkbransjen-spotify-morgan-sulele-katastrofe-anders-nilsen',
#    'published_date': datetime.datetime(2019, 5, 5, 17, 0, tzinfo=TzInfo(UTC)),
#    'title': 'Aslak Klever: Om musikkbransjen, Spotify, Morgan Sulele, Katastrofe, Anders Nilsen +++',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/f04dcb68-df1b-4bf6-9e43-b1490152259b/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 148289996,
#    'guid': 'aebbb586-1b5c-4458-a921-36a478fb9c81',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 9263,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/f04dcb68-df1b-4bf6-9e43-b1490152259b/image.jpg?t=1712349077&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': 'Stian Engebretsen er nordisk mester, har bronse fra EM, og fire norgesmesterskap i Taekwondo. Han har ti års erfaring med MMA, og er fortiden sparketreneren til UFC-fighter Jack Hermansson. Han er også utdannet sivilingeniør i fysikk og matt',
#    'itunes_episode': '5',
#    'description': 'Stian Engebretsen er nordisk mester, har bronse fra EM, og fire norgesmesterskap i Taekwondo. Han har ti års erfaring med MMA, og er fortiden sparketreneren til UFC-fighter Jack Hermansson. Han er også utdannet sivilingeniør i fysikk og matte. Hør Wolfgang Wee Uncut i Spotify Hør Wolfgang Wee Uncut i Apple Podcast Se Wolfgang Wee Uncut på Youtube Ukentlig Nyhetsbrev (påmelding her) Wolfgang Wee Uncut Hjemmeside Instagram Facebook Twitter For podcast tips, podcast anbefalinger, podtoppen, podcast toppen, podkast og en oversikt over alle episodene med Wolfgang Wee Uncut, besøk https://www.pod-cast.no See acast.com/privacy for privacy and opt-out information. See omnystudio.com/listener for privacy information.',
#    'link': 'https://pod.space/wolfgangweeuncut/stian-engebretsen-om-ufc-mma-kampsport-trening-fasting-kosthold-jack-hermansson-emil-meek-joe-rogan',
#    'published_date': datetime.datetime(2019, 4, 28, 2, 0, 43, tzinfo=TzInfo(UTC)),
#    'title': 'Stian Engebretsen: Om UFC, MMA, kampsport, trening, fasting, kosthold, Jack Hermansson, Emil Meek, Joe Rogan +++',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/74e3e120-7c61-479e-9a02-b14901525429/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 217692509,
#    'guid': '21cf088f-6488-4001-a9f0-463f94a87afa',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 13601,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/74e3e120-7c61-479e-9a02-b14901525429/image.jpg?t=1712349117&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': 'Martin Danielle er artisten bak CLMD, og mentor i The Voice på TV2.Hør Wolfgang Wee Uncut i Spotify',
#    'itunes_episode': '4',
#    'description': 'Martin Danielle er artisten bak CLMD, og mentor i The Voice på TV2. Hør Wolfgang Wee Uncut i Spotify Hør Wolfgang Wee Uncut i Apple Podcast Se Wolfgang Wee Uncut på Youtube Ukentlig Nyhetsbrev (påmelding her) Wolfgang Wee Uncut Hjemmeside Instagram Facebook Twitter For podcast tips, podcast anbefalinger, podtoppen, podcast toppen, podkast og en oversikt over alle episodene med Wolfgang Wee Uncut, besøk https://www.pod-cast.no See acast.com/privacy for privacy and opt-out information. See omnystudio.com/listener for privacy information.',
#    'link': 'https://pod.space/wolfgangweeuncut/clmd-martin-danielle-om-housemusikk-axwell-avicii-musikkbransjen-royalties',
#    'published_date': datetime.datetime(2019, 4, 15, 12, 51, 16, tzinfo=TzInfo(UTC)),
#    'title': 'CLMD - Martin Danielle: Om housemusikk, Axwell, Avicii, musikkbransjen, royalties +++',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/16204878-91dd-4578-93db-b149015224d6/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 134351028,
#    'guid': '5c46bd10-7d81-4f94-838a-5b34e3f4c393',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 8392,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/16204878-91dd-4578-93db-b149015224d6/image.jpg?t=1712349075&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': 'Alexander Rykkinnfella Austheim er en Spellemann-belønt musikkprodusent, artist i gruppen JCY, og A&R i Universal Music Norge.Hør Wolfgang Wee Uncut i Sp',
#    'itunes_episode': '3',
#    'description': 'Alexander Rykkinnfella Austheim er en Spellemann-belønt musikkprodusent, artist i gruppen JCY, og A&R i Universal Music Norge. Hør Wolfgang Wee Uncut i Spotify Hør Wolfgang Wee Uncut i Apple Podcast Se Wolfgang Wee Uncut på Youtube Ukentlig Nyhetsbrev (påmelding her) Wolfgang Wee Uncut Hjemmeside Instagram Facebook Twitter For podcast tips, podcast anbefalinger, podtoppen, podcast toppen, podkast og en oversikt over alle episodene med Wolfgang Wee Uncut, besøk https://www.pod-cast.no See acast.com/privacy for privacy and opt-out information. See omnystudio.com/listener for privacy information.',
#    'link': 'https://pod.space/wolfgangweeuncut/rykkinnfella-alexander-austheim-om-karpe-palmesus-avicii-og-stargate-masterclass',
#    'published_date': datetime.datetime(2019, 4, 8, 15, 12, 9, tzinfo=TzInfo(UTC)),
#    'title': 'Rykkinnfella Alexander Austheim: Om Karpe, Palmesus, Avicii og Stargate Masterclass',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/5e83ebea-1005-4803-87c4-b14901525a9d/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 197757090,
#    'guid': '9642df44-3c20-4c3f-a19b-35c66d4259b4',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 12355,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/5e83ebea-1005-4803-87c4-b14901525a9d/image.jpg?t=1712349122&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': 'Anders McAuley er en irsk-norsk standupkomiker, programleder og skuespiller fra Bergen, kjent fra humorprogrammet Kirketid på NRK P3 og Lip Sync Battle på TV2.',
#    'itunes_episode': '2',
#    'description': 'Anders McAuley er en irsk-norsk standupkomiker, programleder og skuespiller fra Bergen, kjent fra humorprogrammet Kirketid på NRK P3 og Lip Sync Battle på TV2. Hør Wolfgang Wee Uncut i Spotify Hør Wolfgang Wee Uncut i Apple Podcast Se Wolfgang Wee Uncut på Youtube Ukentlig Nyhetsbrev (påmelding her) Wolfgang Wee Uncut Hjemmeside Instagram Facebook Twitter See acast.com/privacy for privacy and opt-out information. See omnystudio.com/listener for privacy information.',
#    'link': 'https://pod.space/wolfgangweeuncut/anders-mcauley-om-sensur-humorprisen-samehets-tinder-og-dubai',
#    'published_date': datetime.datetime(2019, 4, 3, 2, 0, 36, tzinfo=TzInfo(UTC)),
#    'title': 'Anders McAuley: Om sensur, humorprisen, samehets, Tinder og Dubai',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Wolfgang Wee',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://traffic.omny.fm/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/ab31f23a-689f-48e2-9630-b149015245f0/audio.mp3?utm_source=Podcast&in_playlist=86067dfc-d436-4194-a175-b149013ac6ef',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 139282925,
#    'guid': 'b3c36c6f-5d6f-49e8-bea1-ce295a51d881',
#    'itunes_author_name': 'Wolfgang Wee',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 8700,
#    'itunes_explicit': None,
#    'itune_image': 'https://www.omnycontent.com/d/clips/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/ab31f23a-689f-48e2-9630-b149015245f0/image.jpg?t=1712349103&size=Large',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': 'Martin Schilde eier produksjonsselskapet Toothfairy og har jobbet ti år i musikkbransjen med artister som CLMD, ARY og Coucheron. Han har også produsert flere dokumentarer, han har vært på Sydpolen, og er utdannet agronom.',
#    'itunes_episode': '1',
#    'description': 'Martin Schilde eier produksjonsselskapet Toothfairy og har jobbet ti år i musikkbransjen med artister som CLMD, ARY og Coucheron. Han har også produsert flere dokumentarer, han har vært på Sydpolen, og er utdannet agronom. See acast.com/privacy for privacy and opt-out information. See omnystudio.com/listener for privacy information.',
#    'link': 'https://pod.space/wolfgangweeuncut/martin-schilde-om-suksesser-og-fiaskoer-i-musikkbransjen-1',
#    'published_date': datetime.datetime(2019, 4, 3, 0, 55, 12, tzinfo=TzInfo(UTC)),
#    'title': 'Martin Schilde: Om suksesser og fiaskoer i musikkbransjen - #1',
#    'podcast_transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None}],
#  'itunes_id': None,
#  'itunes_author_name': 'Wolfgang Wee',
#  'itunes_block': False,
#  'itunes_categories': ['Comedy Interviews', 'Comedy', 'Society & Culture'],
#  'itunes_complete': None,
#  'itunes_explicit': True,
#  'itune_image': None,
#  'itunes_keywords': None,
#  'itunes_new_feed_url': 'https://www.omnycontent.com/d/playlist/d79bdbb3-8eae-4ad2-b1f6-b0bc00cd1540/934cbd67-03d3-4a50-8cdd-b149013ac5fc/86067dfc-d436-4194-a175-b149013ac6ef/podcast.rss',
#  'language': 'no',
#  'last_build_date': None,
#  'link': None,
#  'managing_editor': None,
#  'published_date': None,
#  'pubsubhubbub': None,
#  'owner_name': 'Feliks Hernes',
#  'owner_email': 'feliks@modernemedia.no',
#  'subtitle': 'Wolfgang Wee Uncut | Lange, uredigerte samtaler, om kultur, politikk, samfunn, vitenskap, idrett, trening, kosthold, psykologi og mye mer, med spennende gjester.  For annonsering: info@modernemedia.no eller wolfgangweemailinglist@gmail.com',
#  'title': 'Wolfgang Wee Uncut',
#  'ttl': None,
#  'web_master': None,
#  'feed_url': None,
#  'detected_language': None}

# %%
p = PodcastMetadata(**podcasts[-1].to_dict())
p.dict()
# Out:
# {'categories': [None, None, None, None, None],
#  'copyright': '© 2024 The RedLeaf Fitness Podcast',
#  'creative_commons': None,
#  'description': 'Join Coach Sean Blinch on the RedLeaf Fitness Podcast. The show dedicated to bringing you stories, interviews and conversations about living a healthy, resilient and productive life. Each episode contains real world insight to help you discover the tools and methods you need to become the healthiest, boldest, most motivated you, yet.',
#  'generator': None,
#  'image_title': 'The RedLeaf Fitness Podcast',
#  'image_url': 'https://storage.buzzsprout.com/69q0eg2fshn1449ry4kjrvxf079u?.jpg',
#  'image_link': 'https://www.redleaf.fit',
#  'items': [{'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/14818941-reading-with-ari-ego-is-the-enemy-by-ryan-holiday.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 42011742,
#    'guid': 'Buzzsprout-14818941',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3496,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/nn2ed3ffyms334x26dw8iwdkxcad?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': 'Reading with Ari: Book Review of, Ego Is The Enemy by Ryan Holiday. Join RedLeaf book reviewer Ari as she discusses the complex relationship between self-improvement, fitness, and the dangers of pride. The battle between personal growth and ego is a journey we all face. Our passion for triathlon training is the backdrop for a broader conversation about life\'s obstacles and triumphs. We share anecdotes from our indoor training struggles and the yearning for the liberating embrace of the outdoors while also delving into Ryan Holiday\'s potent message in "Ego is the Enemy." Listen as we dissect the cultural echo chamber that inflates our egos and confuses self-advertising with substantive progress. You\'ll walk away with five transformative takeaways from Holiday\'s work, each marked by a quote that has reshaped our perspective on personal and athletic aspirations. When the starting gun of our endeavours fires, the blend of passion and process keeps our strides steady. This episode peels back the layers of visualization\'s strengths and weaknesses as I recount the visceral power of picturing the Ironman finish line long before the race began. We critique the seductive trap of passion, advocating instead for a foundation of purpose and the grind of disciplined effort. Our discussion turns to Henry Ford\'s wisdom, illustrating that reputation reflects actions, not intentions. This chapter reinforces the importance of embracing the mundane and the methodical, and it will inspire you to honour the quiet dedication that actual ambition demands. In conclusion, we celebrate personal victories and the silent satisfaction of chasing one\'s potential. We tackle the challenging but rewarding task of learning from failure and maintaining humility in our relentless pursuit of personal betterment. From the reflective calm found in a swimmer\'s strokes to the triumphant charge toward our personal bests, we explore the essence of growth and fulfillment. Embrace the insights from this book as you navigate the waters of life, striving for an existence unshackled by ego. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ \'𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING',
#    'link': None,
#    'published_date': datetime.datetime(2024, 4, 3, 5, 0, tzinfo=TzInfo(-04:00)),
#    'title': 'Reading with Ari: Ego Is The Enemy, by Ryan Holiday',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/14818941/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/14593939-are-you-unintentionally-derailing-your-gains-at-the-gym.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 28549154,
#    'guid': 'Buzzsprout-14593939',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 2374,
#    'itunes_explicit': False,
#    'itune_image': 'https://storage.buzzsprout.com/w9s6rwghozrv6z7zhvx8e9xppsdg?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "Join Sean and Michelle as they share stories from the fitness world, uncovering small habits that may be hindering your progress. They cover a range of topics, from serious to seriously funny, to help you overcome everyday fitness challenges. In this session, they discuss the importance of being coachable, especially in CrossFit. It can be difficult to balance your desire for immediate success with your coach's advice for long-term health. Sean shares his personal experience with wanting to outrun his coach's guidance, while Michelle talks about the emotional ties we have to fitness goals. They discuss the benefits of open dialogue with mentors and how it can help align your self-improvement journey with your emotional wellness. Finally, they delve into the practical aspects of setting fitness goals, with a focus on protein intake. They debunk myths, offer nutritional tactics, and emphasize the power of visualization. They also give a sneak peek of Part B of their conversation, which promises to provide even more insights into the world of fitness. So, join Sean and Michelle and let's tackle those fitness dreams together! 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2024, 2, 28, 10, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Are you unintentionally derailing your gains at the gym?',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/14593939/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/14441503-practical-solutions-for-everyday-goals-winter-blues-supplements-and-nutrition.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 26114666,
#    'guid': 'Buzzsprout-14441503',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 2172,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/tmszzji3ev7f4jnxtbbuo4agyvf7?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '1',
#    'description': "Ever felt like winter's gloom has a stranglehold on your smile? Well, buckle up as Coach Michelle and I, Sean Blinch, take you on a journey to wrestle back your joy and kickstart your productivity, even under Toronto's stubborn cloud cover. In our latest episode of the Red Leaf Fitness podcast, we unpack the toolbox for crafting your daily sunshine, from the simple pleasures of a good book to the endorphin rush of your favorite workout. And if you're someone who needs a 'wolf at the door' to chase, we dive into why a looming challenge can be just the ticket to keep the winter blues at bay. Navigating the supplement aisle can feel like a quest without a map, but we've got the compass you've been looking for. Join us as we sift through the avalanche of dietary advice, landing on solid ground with the real MVPs – whey protein, creatine, and the like. As we chuckle over the memory of a shampoo scent, ylang ylang, we don't forget to remind you of the critical step: consulting a healthcare pro before rejigging your supplement stack. Whether you're looking to build muscle or just keep your spirits lifted, we've got the lowdown on what's worth your hard-earned dollars (and what's not). Before you think popping pills is the golden ticket to Hulk-like gains, listen in as we shine a spotlight on the unsung heroes of health – veggies. Yes, you heard us, those green machines might just be your secret weapon in the testosterone department, thanks to a little thing called DIM. But it's not just about what you eat—Michelle and I serve up a reminder that good ol' Z's and a balanced plate are the real cornerstones of peak performance and tip-top testosterone. So if you're ready to put a spring in your step (and your muscles) this winter, give this episode a listen. Coach Michelle and I are all set to guide you through the season with a mix of science, stories, and a sprinkle of humor. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2024, 2, 5, 8, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Practical Solutions for Everyday Goals: Winter Blues, Supplements and Nutrition',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/14441503/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/14359964-practical-solutions-for-everyday-goals-how-to-get-stronger.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 21679628,
#    'guid': 'Buzzsprout-14359964',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 1799,
#    'itunes_explicit': False,
#    'itune_image': 'https://storage.buzzsprout.com/stir85tmr9l2zhbmbhqko1iekymy?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '89',
#    'description': "Are you ready to unlock the secrets to a stronger, healthier, and more joyful life? That's exactly what Michelle and I, promise as we guide you through the transformative power of strength training. Our latest episode isn't just for gym aficionados; it's for anyone aiming to craft a robust life inside and out. From the novice lifting their body weight to the seasoned athlete refining their clean and jerk, we're here with anecdotes, insights, and strategies to help you tailor a plan as unique as your goals. Encountering a plateau in your training can be as frustrating as a barbell that won't budge. But what if I told you that the secret to surpassing your personal best isn't always about piling on more plates? Within the depths of our discussion, we dissect the nuances of technique, the strategy behind regression for progression, and the psychological battle of lifting heavier. It's a narrative that redefines success in weightlifting, replacing the obsession with numbers with a holistic approach to incrementally achieving peak performance and ensuring safety. Sculpting your physique is one piece of the puzzle; the other is nurturing your well-being amidst life's daily hustle. Michelle and I explore the essential acts of self-care that foster stress management and invite joy into your routine. From setting boundaries to unwinding with intention, we share practical steps to improve not only your evenings but also your mornings and, ultimately, your life. So, tune in and let us accompany you on a journey that's not just about getting stronger but also about embracing happiness every step of the way. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2024, 1, 23, 4, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Practical Solutions for Everyday Goals: How To Get Stronger',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/14359964/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/14325549-practical-solutions-for-everyday-goals-how-to-achieve-new-years-resolutions.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 18589203,
#    'guid': 'Buzzsprout-14325549',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 1545,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/9rizulm77sdaot1hqnxpuqowg25c?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '88',
#    'description': "Wave goodbye to those lofty New Year's resolutions that never stick and say hello to turning big dreams into daily habits with us, Sean Blinch and Michelle—your guides to a fitter, happier you. This episode is a goldmine for anyone who's ever found themselves scribbling ambitious fitness goals but come February, can't even find the pen. We're swapping out over-the-top aspirations for realistic, bite-size actions, because let's face it, prepping for a triathlon doesn't happen overnight. From maintaining a simple hydration streak to leveraging the psychological power of habit-building apps, we're laying down the foundation for a year where your fitness routine actually becomes routine. Ready to lace up your sneakers for the Gravenhurst triathlon or just aiming to run your first full lap around the park? Our latest chat is all about the personal triumphs that come from pushing just a bit further each day. We give you the insider scoop on community events and training opportunities that'll have you biking, swimming, and running alongside fellow enthusiasts. Joining forces with Coach Karen for a cycling session or diving in with Coach Tara for a team swim not only offers guidance but fuels the camaraderie that keeps the spirit of competition friendly and your personal goals within reach. As we wrap up, don't forget that our Zoom calls are the virtual place to be for anyone targeting races, be it a duathlon, a 10K, or the Gravenhurst triathlon. It's not all split times and race strategies; we're dishing out wisdom that transcends the track, keeping you in the loop with newsletters and community updates that will ensure 2024 is more than just a leap year—it's your leap forward. Join Michelle and me as we step into a year of shared victories, growth, and a community cheering you on at every mile marker. Here's to the progress we make each day and the wins we'll celebrate together. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2024, 1, 17, 3, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Practical Solutions for Everyday Goals: How To Achieve New Years Resolutions!',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/14325549/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/14224776-the-athletic-journey-of-ultraman-champion-tara-norton.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 48595715,
#    'guid': 'Buzzsprout-14224776',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 4045,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/ujbjbv3ev70pmqn2advwmf44pt9r?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '87',
#    'description': "Embark on an extraordinary expedition through the life of Tara Norton, an athlete whose dedication to sports began under the Toronto skyline. We uncover the layers of Tara's formative years, we're reminded that the fire of competition is kindled in the playgrounds of our youth. You'll be drawn into the world of a young girl whose parents' encouragement paved the way for a life rich in athletic pursuit, only to find that the allure of high school social life momentarily eclipsed her passion for the pool. However, the embers of competition never truly cooled. Tara's story reignites with a zeal for sports as we trace her journey from a hesitant high schooler to a university standout. Tune in to hear how Tara wove her way through the demanding tapestry of collegiate swimming and rowing, only to stumble upon the alluring challenge of triathlons. She vividly recounts the evolution of her technique, the gruelling training regimens, and the unique voracity that follows a swimmer's workout. From the serene rowing mornings that could have led to Olympic dreams to the adrenaline-fueled transitions of triathlon, Tara's narrative is a testament to the adaptability and prowess of an athlete who found her true calling on the triathlon circuit. Her reflections on Ironman successes reveal not just the physical strength required, but the mental fortitude that becomes the true hallmark of a pro. As our conversation winds down, Tara shares the intimate dance of balancing the rigours of motherhood with the relentless pull of competition. Her resilience in the face of injury and the sheer willpower to overcome serve as a beacon to all who face adversity. From professional triumphs to the Ultraman challenges, Tara embodies the spirit of perseverance. Her journey isn't solely about athletic conquests; it's a profound exploration of the human condition and the unwavering pursuit of what ignites our souls with passion. Join us for this episode as we celebrate the indomitable spirit of Tara Norton, a narrative that affirms the transformative power of dedicated pursuit in sports and in life. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2023, 12, 31, 4, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'The Athletic Journey of Ultraman Champion Tara Norton',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/14224776/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/14054718-finn-rayner-navigating-teenage-life-an-honest-inside-look-at-high-school-struggles-triumphs-and-personal-growth.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 48883365,
#    'guid': 'Buzzsprout-14054718',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 4068,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/k0byyddg55nerzatdp0m17u3p9sq?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '87',
#    'description': "In this interview, we sit down with teenager Finn Rayner to explore the crucial transition period of high school. We delve into the impact of the pandemic on the academic and social aspects of high school life and how it has affected Finn. He offers an honest perspective of his struggles with online learning and the social pressures associated with this phase of life. We also address the subject of drug use among teenagers and emphasize the crucial role of parents in teaching children about the consequences of their actions. During the conversation, we discuss the complexities of personal growth and the significance of familial relationships. Finn shares his journey of dealing with the loss of his father amidst the rigours of teenage life. He enlightens us with his candid thoughts on emotional maturity, the value of friendship, and the unyielding support offered by his family. We also talk about the pressure high school students face regarding future plans and the importance of living in the present. Finn shares his aspiration to visit Nepal and learn about a different culture. The episode concludes with a tribute to Finn's parents' influential role in shaping his life. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2023, 11, 29, 3, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Finn Rayner: Navigating Teenage Life, An Honest Inside Look at High School Struggles, Triumphs, and Personal Growth',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/14054718/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/14017464-reading-with-ari-scarcity-brain-by-michael-easter.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 53004571,
#    'guid': 'Buzzsprout-14017464',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 4412,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/imzdxaeydevsn1caq0lcfuxxukvz?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '86',
#    'description': 'In our latest podcast episode, my guest Ari and I discuss Michael Easter\'s book "Scarcity Brain." We explore how our survival instincts and scarcity cues can keep us trapped in a cycle of insatiability, and the far-reaching implications of scarcity and numbers in our daily decisions. We also tackle the controversial topic of cancel culture and the alarming rise of overthinking and offer practical guidance to foster contentment through gratitude, meditation, and wise decision-making. Tune in now for a deep understanding of how scarcity influences our lives and how we can combat its effects. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ \'𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING',
#    'link': None,
#    'published_date': datetime.datetime(2023, 11, 22, 6, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Reading with Ari: Scarcity Brain by Michael Easter',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/14017464/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/13841890-alyssa-ages-author-of-secrets-of-giants-shares-her-empowering-story-of-trials-triumphs-and-lifting-heavy-things.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 34283485,
#    'guid': 'Buzzsprout-13841890',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 2851,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/9evsjc4w4ihxdnhfbggjxa7zo67z?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '85',
#    'description': "Alyssa Ages, author of Secrets of Giants, shares her empowering journey of lifting heavy things and its life-changing impact on her. Alyssa's story is a testament to resilience, overcoming profound heartache after a miscarriage to find solace and healing in strength training. Her path from 'being the unathletic kid' to a strongman competitor and endurance athlete is nothing short of inspiring. Alyssa opens up about her fears, trials, and triumphs, including competing in a marathon and a half Ironman triathlon, which she embarked on despite not knowing how to swim at the outset. Her story proves strength is more than physical - it's about emotional fortitude and mastering the unexpected. But Alyssa's journey isn't a solitary one. She talks about her coach's critical role in her transformation, offering support for both the physical rigours of training and the emotional challenges that came with it. Moreover, Alyssa reveals the unexpected hurdles of writing a book and the power of vulnerability in sharing her story. Join us for an engaging conversation beyond muscle and sinew to explore emotional resilience and the real meaning of strength. Book Available now! https://www.penguinrandomhouse.ca/books/707130/secrets-of-giants-by-alyssa-ages/9780593539408 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2023, 10, 25, 4, 0, tzinfo=TzInfo(-04:00)),
#    'title': 'Alyssa Ages, author of Secrets of Giants, shares her empowering story of trials, triumphs and lifting heavy things',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/13841890/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/13583165-the-crossfit-games-journey-with-kevin-cunningham-and-trenton-mackenzie-armes-triumphs-trials-and-training.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 69286806,
#    'guid': 'Buzzsprout-13583165',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 5768,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/imf6vfrr2ba16gfipiuoja4oer71?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '84',
#    'description': "Join us on an exhilarating journey as we chat with CrossFit Games athlete Kevin Cunningham with his long-time friend and Coach Trenton MacKenzie Armes, who take us through the trials and triumphs of their journey to the CrossFit Games. The duo opens up about their inspirations and sheds light on how they prepared for the competition and the community that rallied around them. A special mention of Nicole Corriero, a previous guest, who was pivotal in inspiring Kevin to take on this challenge. No sporting prowess can be achieved without dedication and discipline. Kevin gives us a peek into his disciplined approach with his home gym and how it has been instrumental in his fitness journey. They also touch upon the revolutionary fitness thinking that CrossFit propagates and its role in their achievements. Furthermore, they give us an inside look into the logistics of the competition, the camaraderie amongst the athletes, and the reality of balancing family life with intense training regimes. A heartwarming story from Kevin about a conversation with his daughter will leave you reflecting on the personal sacrifices athletes often make. As we move to the final segment, we touch upon the challenges and stresses associated with CrossFit competitions. As we close, we excitedly discuss Kevin and Trenton's upcoming adventure - the Traverse. This four-day trek in the Tobacco Route Mountains of Montana will test their endurance and survival skills. This episode is a treasure trove of insights, revelations, and the true essence of what it takes to be an athlete of their calibre. So sit back, tune in, and prepare to be inspired to KEEP GOING. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2023, 9, 13, 5, 0, tzinfo=TzInfo(-04:00)),
#    'title': 'The CrossFit Games Journey with Kevin Cunningham and Trenton MacKenzie Armes: Triumphs, Trials, and Training',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/13583165/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/13539812-ayesha-rollinson-founder-of-team-atomica-a-story-of-athletic-triumph-and-entrepreneurship.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 57370417,
#    'guid': 'Buzzsprout-13539812',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 4776,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/rm0w6ln8uq4keluabnby1t4gjqpz?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '83',
#    'description': "Join us as we journey alongside our guest Ayesha Rollinson, founder of Team Atomica, from her engineering career to her pursuit of an Olympic spot, only to find her calling in coaching. Now leading a masters swim and triathlon club based in Toronto, Ayesha and the incredible coaches of Team Atomica are transforming lives, including Coach Seans, by helping athletes improve their swimming and introducing them to the world of triathlons. Uncover how the love of challenges and problem-solving manifested in Ayesha from a young age and led to her organizing and winning her first half marathon at 12 years old. Hear first-hand how her family's support fueled her competitive spirit and influenced the athletic success of her and her siblings. Ayesha’s refusal to adhere to gender norms, disciplinary boundaries and the power of words in coaching form the backbone of her inspiring story, one that will resonate with anyone who's faced hurdles and found ways to leap over them. Discover the balance between entrepreneurship, family, and training that Ayesha has skillfully managed and the philosophies that guide Team Atomica. As we delve into Ayesha’s life as an entrepreneur, you’ll gain insights into the rewarding nature of coaching and the profound gratitude it brings. So, get ready for a transformative journey, expect to be moved, and come away inspired by Ayesha's dedication to creating an accessible and supportive athletic community. Learn More: https://teamatomica.com/ 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2023, 9, 6, 8, 0, tzinfo=TzInfo(-04:00)),
#    'title': 'Ayesha Rollinson, Founder of Team Atomica: A Story of Athletic Triumph and Entrepreneurship',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/13539812/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/13458192-anything-is-possible-coach-sean-s-journey-to-becoming-an-ironman.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 69432427,
#    'guid': 'Buzzsprout-13458192',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 5780,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/fmnv4pf8479nrjugptmxyrv20z1a?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '82',
#    'description': "Join me as I open up about my journey from competing in an Olympic distance triathlon to facing the most difficult mental and physical test of my life: becoming an Ironman. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2023, 8, 23, 13, 0, tzinfo=TzInfo(-04:00)),
#    'title': "Anything is Possible: Coach Sean's Journey to Becoming an Ironman",
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/13458192/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/13276034-reading-with-ari-book-reviews-the-comfort-crisis-by-michael-easter.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 48298915,
#    'guid': 'Buzzsprout-13276034',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 4021,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/ja2ivtdqpgos3u3ovqvk7fl5woqo?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '81',
#    'description': 'What if the very comforts we relish in the modern world were actually hampering our happiness and wellness? That\'s the riveting question we explore with Michael Easter\'s, book "The Comfort Crisis," in our latest episode. We engage in an eye-opening discussion about the impact of our smartphones, temperature-controlled environments, and other conveniences on our health, as well as the life-altering power of stepping outside our comfort zones. Michael\'s personal accounts from his 33-day expedition in Alaska offer invaluable insights into our quest for comfort. The episode takes an intriguing turn as we wade into the oft-debated waters of meat consumption. From the ethics of hunting to the distinctive flavor of pasture-raised meat, we dissect the subject from all angles, while emphasizing the need for mindful consumption. We also spotlight the merits of "voting with your money," advocating for consumers to make choices that align with their values and principles. The conversation then veers towards Masogi, a term coined by Dr. Marcus Elliot, signifying pushing the boundaries of human potential – a must-listen for anyone eager to challenge themselves and expand their horizons. Rounding off the episode, we delve into a deeper understanding of solitude and its dichotomous nature – often perceived as a sign of weakness and a gateway to self-discovery. Our chat highlights the importance of getting comfortable with being alone, fostering self-awareness, and developing authenticity in relationships. We conclude by sharing stories about Brazil and Canada\'s starkly different camping experiences. This episode is a treasure trove of insights for fitness enthusiasts, adventurers, and anyone keen on challenging societal norms and pushing personal boundaries. Tune in for an enlightening journey that might just motivate you to step outside your comfort zone. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ \'𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING',
#    'link': None,
#    'published_date': datetime.datetime(2023, 7, 24, 3, 0, tzinfo=TzInfo(-04:00)),
#    'title': 'Reading With Ari, Book Reviews, "The Comfort Crisis" by Michael Easter',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/13276034/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/13207620-alba-s-gravenhurst-triathlon-race-report-and-the-transformative-power-found-within.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 43072354,
#    'guid': 'Buzzsprout-13207620',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3584,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/2669kdps9q3zz55ep38f2mpp8lbv?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '80',
#    'description': "Join us on a thrilling journey with today's guest, Alba, as she shares her inspiring story from her first swim lesson to becoming a triathlete. She recounts braving icy winter swims, juggling a new job, and participating in two CrossFit competitions that led up to her exhilarating day at the triathlon. In this episode, you'll experience the excitement of a triathlon race day through Alba's eyes. She vividly describes every detail, from the meticulous pre-race nutrition plan and the bustling atmosphere of the gear setup, to the unique boat start and the transition from swimming to biking. Alba also shares how she used positive self-talk and pacing to find her rhythm in the water, and how her CrossFit experience powered her through. Alba's journey is a testament to the power of a positive mindset and the importance of a strong support system. She credits CrossFit as a significant contributor to her triathlon success and shares valuable tips for anyone aspiring to take on this challenge. We conclude our chat by reflecting on the magic of the journey and the importance of relishing every part of the race. Get ready to be inspired to conquer your own fitness challenges. Tune in to witness the making of a triathlete! 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2023, 7, 12, 4, 0, tzinfo=TzInfo(-04:00)),
#    'title': "Alba's Gravenhurst Triathlon Race Report and the transformative power found within",
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/13207620/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/13077510-finding-meaning-in-medicine-and-overcoming-adversity-a-surgeon-s-journey-so-far.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 43211495,
#    'guid': 'Buzzsprout-13077510',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3596,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/1z2w4qlhetne1rfpccngareubcxo?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '79',
#    'description': "When was the last time you heard an inspiring life story of a surgeon who overcame adversity to achieve his dreams? Join me as I sit down with Dr. Andrew Feifer, MD, Urologic Oncology, to discuss his life journey, from his childhood in Montreal to becoming a successful surgeon and the impact of his mother's experience on his path. We delve into his intense conversations with patients, his commitment to providing hope and confidence, and the balance of risks and rewards that come with being a surgeon. Throughout our conversation, Dr. Feifer opens up about the importance of self-care and shares his insights on prioritizing oneself to give more to others. We discuss his experiences working with a diverse and skilled team of medical professionals and the importance of mentorship for new surgeons. We also explore the potential for fitness facilities like RedLeaf to collaborate with physicians in optimizing wellness. Finally, Dr. Feifer emphasizes the importance of living a meaningful life and maximizing our time on earth. Don't miss this inspiring and insightful conversation with Dr. Andrew Feifer, where we learn about the challenges, rewards, and dedication it takes to become a successful surgeon and how prioritizing self-care can lead to a more fulfilling life. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2023, 6, 20, 17, 0, tzinfo=TzInfo(-04:00)),
#    'title': "Finding Meaning in Medicine and Overcoming Adversity: a Surgeon's Journey So Far",
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': {'type': 'application/json',
#     'url': 'https://www.buzzsprout.com/1507828/13077510/chapters.json'},
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/13050796-the-unstoppable-karen-lue-from-small-town-girl-to-ironman-triathlete.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 50673449,
#    'guid': 'Buzzsprout-13050796',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 4217,
#    'itunes_explicit': False,
#    'itune_image': 'https://storage.buzzsprout.com/842rpdkwf0142pathf8kuovin9n8?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '78',
# ...
#    'itunes_summary': None,
#    'itunes_episode': '7',
#    'description': "Julie opens up about struggling with an eating disorder, about the importance of truly accepting yourself, we also talk about the inspiring mission baked right into the DNA of her company, with lots of great business and life pearls along the way. Julie and I may have trained together a long time ago now but she left a mark on me and we’ve always stayed in touch. Julie's energy and zeal for life is so infectious and I hope you take away as much as I did in this interview. And remember if you like what we’re putting down today we would love it if you could subscribe, rate and share our podcast! Questions for Julie What's your story? And how did you meet Sean? What do you do for work? Can you tell us the story behind The Healthy Crunch? How do you keep the balance in your life? What does healthy living mean to you? What advice would you give young entrepreneurs about starting a business? https://healthycrunch.com/ 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2021, 1, 3, 12, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Ep.7 | Founder, CEO of The Healthy Crunch opens up about winning a battle with a decade long eating disorder, self acceptance, fitness, Women-owned businesses and more.',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/7047751-ep-6-crossfit-we-re-back-what-happened-and-why-we-re-back.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 24792098,
#    'guid': 'Buzzsprout-7047751',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 2062,
#    'itunes_explicit': False,
#    'itune_image': 'https://storage.buzzsprout.com/co5ra4vdteggzshyiaswqce8l2pm?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '6',
#    'description': "Read our full statement on our blog: https://www.redleaf.fit/post/crossfit-were-back RedLeaf Fitness, after careful consideration, has decided to embrace the CrossFit brand again, believing the changes promised by the new management team mean we can resume the journey with all its original promise. As we all know, insensitive comments by top leadership at CrossFit Home Office earlier this year cratered an already difficult relationship with boxes around the world, including at RedLeaf. But it was a tough decision to leave. Toronto’s RedLeaf Fitness had long believed that CrossFit is the most potent fitness vehicle in the world. No other methodology can deliver results that are as broad, lasting, and dynamic. Is this Episode Coach Michelle and Coach Sean speak from the heart about what it means to them to return to the brand they fell in love with over 10 years ago. They believed in its ability to bring people together, to share in a common goal, and to inspire each other to be better. CrossFit has helped us all through rough times. It has been the tool that shapes the lives of the people we work with. And it is the common thread that brings us together. We are excited to become an affiliate again because of the changes that CrossFit has committed to making. We believe in Roza, and we believe that he understands the challenges facing the affiliates. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2020, 12, 29, 9, 0, tzinfo=TzInfo(-05:00)),
#    'title': "Ep.6 | CrossFit: WE'RE BACK.  (What happened and why we're back)",
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/6914201-ep-5-valerie-boileau-on-breaking-body-image-barriers-and-the-meaning-of-crossfit.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 33590599,
#    'guid': 'Buzzsprout-6914201',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 2795,
#    'itunes_explicit': False,
#    'itune_image': 'https://storage.buzzsprout.com/hpmgfat50z0n53csjv92j3lbqvhq?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '5',
#    'description': "🎙On Episode 5 of The RedLeaf Podcast Coach @seanblinch sits down to talk with Valerie Boileau (@valboileau). Val is a strength and conditioning Coach based out of Montreal Canada, she holds her CrossFit Level 3 and works for CrossFit HQ travelling the world delivering educational seminars. Val shares her story, opens up about breaking barriers on body image, and talks about how to level up during the pandemic, prepare to be inspired when you hear what CrossFit means to her. 🗣 Questions for Valerie 🧠 What's your story? 🧠 How and when did you find fitness? 🧠 What do you do for work? 🧠 How has the pandemic been? What do you do to keep focused and healthy? 🧠 What are your goals for 2021? ❤️ Keep lifting each other up. \u2060 #KEEPGOING \u2060 www.redleaf.fit 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2020, 12, 18, 14, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Ep.5 | Valérie Boileau on breaking body image barriers and the meaning of CrossFit',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/6842167-ep-4-geoff-carnevale-on-business-mortgages-fitness-golf-and-day-to-day-principles-geoff-uses-for-living-the-good-life.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 40315075,
#    'guid': 'Buzzsprout-6842167',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3356,
#    'itunes_explicit': True,
#    'itune_image': 'https://storage.buzzsprout.com/0x1eaq4p86g00pek0sdahnower4k?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '4',
#    'description': "🎙 On Episode 4 of The RedLeaf Fitness Podcast Coach @seanblinch sits down to talk with long time personal training client, #Entrepreneur and Mortgage broker Geoff Carnevale (@geoff_carney). They talk about Geoff running his own business (link below), the ins and outs of home owning finances, fitness, golf, and day to day principles Geoff uses for living the good life. Questions for Geoff Who is Geoff Carnevale? Should I go Fixed or Variable Mortgage What's the difference between a broker and my bank? What's your lowest rate? Term? What should my amortization be? How do I choose a mortgage broker? http://www.admoremortgage.com/ 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2020, 12, 14, 12, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Ep.4 | Geoff Carnevale on business, mortgages, fitness, golf, and day to day principles Geoff uses for living the good life.',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': None,
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/6731029-ep-3-trent-mackenzie-armes-on-resilience-balancing-fitness-work.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 42423352,
#    'guid': 'Buzzsprout-6731029',
#    'itunes_author_name': None,
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 3530,
#    'itunes_explicit': False,
#    'itune_image': 'https://storage.buzzsprout.com/v9z8i18l8ttmakxoachvm1vcplj8?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '3',
#    'description': "Today I sit down to talk with my long time personal training client Trent to talk about growing up, fitness, work stress and how to find meaning in it all. Trent and I have trained together for over 10 years, he’s moved multiple gyms with me and he’s also been an incredibly important mentor to me in my growth both personally and professionally. I had a blast sitting down and chatting with Trenton and so wherever this podcast finds you today whether it be out on a walk, crushing your to do list or in the car on route somewhere I hope you find some value in our sound byte conversation and hope you learn something about someone who’s quite special to me. And remember if you like what we’re putting down today we would love it if you could subscribe, rate and share our podcast! 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2020, 12, 8, 14, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Ep.3 | Trent MacKenzie-Armes on Resilience, Balancing Fitness & Work',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/6658177-ep-2-scott-blinch-the-web-sheriff-runner-front-end-web-developer-good-guy.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 21838934,
#    'guid': 'Buzzsprout-6658177',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 1815,
#    'itunes_explicit': False,
#    'itune_image': 'https://storage.buzzsprout.com/j1vmv0ldm4aohwzvgqzk4anx6p8u?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '2',
#    'description': 'Check out Ep. 2 | "The Web Sheriff" 🎙 on The RedLeaf Fitness Podcast with Runner, Web Developer, RedLeaf Website Designer @scottblinch now. On this episode Scott and Coach Sean sit down and jam out about Fitness Technology and how it was effected by the Global Pandemic and how we can take nothing for granted. 🎧 🎙 Introducing The RedLeaf Fitness Podcast "Fitness is not just a lifestyle anymore. Join Coach Sean Blinch on the show that explores the vital nexus of fitness and health—and why it’s more important than ever to get the best advice on optimizing your well being. Each episode contains powerful information to help you burnish your physical armour, ways to stay motivated, and ultimately why we KEEP GOING." ❤️ Keep lifting each other up. \u2060 \u2060 #KEEPGOING \u2060 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ \'𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING',
#    'link': None,
#    'published_date': datetime.datetime(2020, 12, 2, 14, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Ep.2 | Scott Blinch - The Web Sheriff, Runner, Front End Web Developer, Good guy',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'episode_id': None,
#    'feed_id': None,
#    'author': 'Sean Blinch',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/1507828/6532315-ep-1-michelle-dukowski-co-founder-trainer-crossfitter.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 22938638,
#    'guid': 'Buzzsprout-6532315',
#    'itunes_author_name': 'Sean Blinch',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': 1908,
#    'itunes_explicit': False,
#    'itune_image': 'https://storage.buzzsprout.com/w3bzww9ynj8mi7ew345jwwp82u2f?.jpg',
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '1',
#    'description': "On our first podcast ever Michelle and I sit down to talk about a little about her story, the pandemic, finding ways to stay motivated and ultimately why we KEEP GOING. 🧠 This episode and more are available now on all streaming platforms. Check it out on Spotify, iTunes or http://podcast.redleaf.fit/ '𝐓𝐡𝐞 𝐑𝐞𝐝𝐋𝐞𝐚𝐟 𝐅𝐢𝐭𝐧𝐞𝐬𝐬 𝐏𝐨𝐝𝐜𝐚𝐬𝐭 𝐢𝐬 𝐚 𝐬𝐡𝐨𝐰 𝐝𝐞𝐝𝐢𝐜𝐚𝐭𝐞𝐝 𝐭𝐨 𝐛𝐫𝐢𝐧𝐠𝐢𝐧𝐠 𝐲𝐨𝐮 𝐬𝐭𝐨𝐫𝐢𝐞𝐬, 𝐢𝐧𝐭𝐞𝐫𝐯𝐢𝐞𝐰𝐬 𝐚𝐧𝐝 𝐜𝐨𝐧𝐯𝐞𝐫𝐬𝐚𝐭𝐢𝐨𝐧𝐬 𝐚𝐛𝐨𝐮𝐭 𝐥𝐢𝐯𝐢𝐧𝐠 𝐚 𝐡𝐞𝐚𝐥𝐭𝐡𝐲, 𝐫𝐞𝐬𝐢𝐥𝐢𝐞𝐧𝐭 𝐚𝐧𝐝 𝐩𝐫𝐨𝐝𝐮𝐜𝐭𝐢𝐯𝐞 𝐥𝐢𝐟𝐞. ⛏️💎#KEEPGOING",
#    'link': None,
#    'published_date': datetime.datetime(2020, 11, 24, 11, 0, tzinfo=TzInfo(-05:00)),
#    'title': 'Ep.1 | Michelle Dukowski - Co Founder, Trainer, CrossFitter',
#    'podcast_transcripts': None,
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None}],
#  'itunes_author_name': 'Sean Blinch',
#  'itunes_block': False,
#  'itunes_categories': ['Health & Fitness',
#   'Business',
#   'Entrepreneurship',
#   'Health & Fitness',
#   'Nutrition'],
#  'itunes_complete': None,
#  'itunes_explicit': False,
#  'itune_image': None,
#  'itunes_keywords': None,
#  'itunes_new_feed_url': None,
#  'language': 'en-us',
#  'last_build_date': datetime.datetime(2024, 4, 3, 6, 14, 10, tzinfo=TzInfo(-04:00)),
#  'link': None,
#  'managing_editor': None,
#  'published_date': None,
#  'pubsubhubbub': None,
#  'owner_name': 'Sean Blinch',
#  'owner_email': None,
#  'subtitle': None,
#  'title': 'The RedLeaf Fitness Podcast',
#  'ttl': None,
#  'web_master': None}

# %%
podcasts[0].to_dict()
# Out:
# {'categories': [None, None, None, None, None],
#  'copyright': '© 2024 Mercia Podcast',
#  'creative_commons': None,
#  'description': 'Keeping you abreast with the latest developments in the accountancy profession.',
#  'generator': None,
#  'image_title': 'Mercia Podcast',
#  'image_url': 'https://storage.buzzsprout.com/2tvhhcz35n6p83nlt9f3mimkoeye?.jpg',
#  'image_link': 'https://www.mercia-group.com',
#  'image_width': None,
#  'image_height': None,
#  'items': [{'author': 'Helen Knight and James Hurst ',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14912612-tax-administration-and-maintenance-day.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 16110332,
#    'guid': 'Buzzsprout-14912612',
#    'itunes_author_name': 'Helen Knight and James Hurst ',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1340',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '62',
#    'description': "<p>Helen Knight and James Hurst discuss the releases from Tax Administration and Maintenance Day on 18 April 2024 particularly the consultation launched around the VAT treatment of private hire vehicle fares.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Thu, 18 Apr 2024 15:00:00 +0100',
#    'title': 'Tax Administration and Maintenance Day',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Lee Eagling, Jenny Faulkner, and Zain Talaat ',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14826242-technology-in-practice.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 32644366,
#    'guid': 'Buzzsprout-14826242',
#    'itunes_author_name': 'Lee Eagling, Jenny Faulkner, and Zain Talaat ',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '2718',
#    'itunes_explicit': 'true',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '61',
#    'description': "<p>Lee Eagling, Jenny Faulkner, and Zain Talaat discuss the emergence of technology in the profession, and how technology can benefit firms of all sizes.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Thu, 04 Apr 2024 13:00:00 +0100',
#    'title': 'Technology in Practice',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/14826242/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Gavin Leake and Lee Eagling',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14683839-ethics-in-accountancy.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 20360784,
#    'guid': 'Buzzsprout-14683839',
#    'itunes_author_name': 'Gavin Leake and Lee Eagling',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1694',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '60',
#    'description': "<p>Lee Eagling and Gavin Leake discuss the importance of ethics in the accountancy profession and the issues and dilemmas those in the profession may face.\xa0 \xa0</p><p><a href='https://www.mercia-group.com/train-overview/train-listing/train-product?id=248749&amp;productitemid=47536'><b>CLICK HERE</b></a><b> for our upcoming Ethics course. \xa0<br/></b><br/></p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': 'https://www.mercia-group.com/train-overview/train-listing/train-product?id=248749&productitemid=47536',
#    'published_date': 'Mon, 25 Mar 2024 08:00:00 +0000',
#    'title': 'Ethics in Accountancy',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14735717-hmrc-backtrack-on-helpline-closure.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 1293064,
#    'guid': 'Buzzsprout-14735717',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '105',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>Join Mark Morton for a brief yet crucial update as he reveals HMRC&apos;s latest decision to halt the closure of its phone lines.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Thu, 21 Mar 2024 09:00:00 +0000',
#    'title': 'HMRC Backtrack on Helpline Closure',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14728469-hmrc-helpline-support-faces-permanent-cutbacks.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 1660474,
#    'guid': 'Buzzsprout-14728469',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '136',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>In this episode, Mark Morton discusses how the HMRC is encouraging customers to interact online with changes to its Self-Assessment, PAYE and VAT services.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 20 Mar 2024 09:00:00 +0000',
#    'title': 'HMRC Helpline Support Faces Permanent Cutbacks',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Louise Connor',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14642894-emotional-intelligence.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 7163697,
#    'guid': 'Buzzsprout-14642894',
#    'itunes_author_name': 'Louise Connor',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '594',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '58',
#    'description': "<p>In this episode, Louise Conner talks about her own experience using emotional intelligence (EQ) to navigate emotions. She also shares practical tips on developing your EQ, helping you understand and manage your own feelings as well as those of others.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Fri, 15 Mar 2024 08:00:00 +0000',
#    'title': 'Emotional Intelligence',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/14642894/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mark Morton and Pat Nown',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14651482-spring-budget-2024.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 12689549,
#    'guid': 'Buzzsprout-14651482',
#    'itunes_author_name': 'Mark Morton and Pat Nown',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1055',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '59',
#    'description': "<p>In this episode, Pat Nown and Mark Morton unpack the key Spring Budget announcements. Gain valuable insights as they analyse fiscal developments and discuss the budget&apos;s impact on various sectors. Whether you&apos;re a finance enthusiast or seeking a concise overview, this conversation goes beyond the headlines, offering a quick yet comprehensive understanding of the current economic landscape.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Fri, 08 Mar 2024 16:00:00 +0000',
#    'title': 'Spring Budget 2024',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/14651482/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mark Morton',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14638914-spring-budget-2024-early-reflections.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 2007467,
#    'guid': 'Buzzsprout-14638914',
#    'itunes_author_name': 'Mark Morton',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '165',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '58',
#    'description': "<p>In this short episode join Mark Morton as he reflects on the Spring Budget announcement delivered by Chancellor Jeremy Hunt today (6 March). <br/><br/>Don&apos;t forget to register for <a href='https://www.mercia-group.com/train-overview/train-listing/train-product?id=275300&amp;productitemid=49525&amp;utm_source=LinkedIn&amp;utm_medium=Social&amp;utm_term=&amp;utm_content=&amp;utm_campaign=MC121_04'>Mercia&apos;s Rapid Reaction Webinar</a> on (7 March) and listen to Pat Nown review the announcements made and consider any immediate implications and actions for your clients.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 06 Mar 2024 14:00:00 +0000',
#    'title': 'Spring Budget 2024 - Early reflections',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/14638914/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Helen Knight & Mark Morton',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14421230-r-d-the-current-state-of-play.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 8409464,
#    'guid': 'Buzzsprout-14421230',
#    'itunes_author_name': 'Helen Knight & Mark Morton',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '698',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '57',
#    'description': "<p>Considers the changes to the regime that the Government has implemented over the last 12 months and the changes yet to come.\xa0<br/><br/>Presented by Mark Morton, our Technical Lecturer and Consultant, and Helen Knight, our Tax Senior Manager.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Mon, 05 Feb 2024 08:00:00 +0000',
#    'title': 'R&D The Current State of Play',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Norman Allison',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14233738-agent-update-issue-115.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 8177705,
#    'guid': 'Buzzsprout-14233738',
#    'itunes_author_name': 'Norman Allison',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '679',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '56',
#    'description': "<p>Happy New Year! In this episode Norman Allison looks at the\xa0 IR35 opportunity to pause settlement, digital signatures, S455 L2P forms, CGT property returns, IR35 guidelines for compliance and BACS notifications.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Tue, 02 Jan 2024 11:00:00 +0000',
#    'title': 'Agent Update Issue 115',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/14233738/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Lee Eagling and Jenny Faulkner',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14055357-common-themes-in-audit-quality.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 23087678,
#    'guid': 'Buzzsprout-14055357',
#    'itunes_author_name': 'Lee Eagling and Jenny Faulkner',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1921',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '55',
#    'description': "<p>Lee Eagling is joined by Jenny Faulkner to discuss the themes highlighted by Mercia’s internal file review quality review checks and compare these to recent audit monitoring findings issues by the QAD.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 29 Nov 2023 13:00:00 +0000',
#    'title': 'Common Themes in Audit Quality',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/14055357/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mark Morton, Technical Lecturer & Consultant',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/14018075-autumn-statement-2023.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 3248211,
#    'guid': 'Buzzsprout-14018075',
#    'itunes_author_name': 'Mark Morton, Technical Lecturer & Consultant',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '268',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '54',
#    'description': "<p>Mark Morton&apos;s initial reaction to the Autumn Statement 2023.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 22 Nov 2023 13:00:00 +0000',
#    'title': 'Autumn Statement 2023',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/14018075/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Lee Eagling, A&A and Compliance Senior Manager',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13902567-recent-audit-sanctions-and-the-link-to-general-audit-quality.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 17112103,
#    'guid': 'Buzzsprout-13902567',
#    'itunes_author_name': 'Lee Eagling, A&A and Compliance Senior Manager',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1423',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '53',
#    'description': "<p>Lee Eagling discusses recent audit sanctions and how findings from these cases link to audit quality issues we find in our file reviews.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Fri, 03 Nov 2023 15:00:00 +0000',
#    'title': 'Recent Audit Sanctions and the Link to General Audit Quality',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13902567/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mark Morton, Technical Lecturer & Consultant',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13800551-recent-cases-on-domicile.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 5663185,
#    'guid': 'Buzzsprout-13800551',
#    'itunes_author_name': 'Mark Morton, Technical Lecturer & Consultant',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '469',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '52',
#    'description': "<p>Mark Morton takes a look at the approach which the Tribunal is taking on domicile in recent cases.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Fri, 20 Oct 2023 08:00:00 +0100',
#    'title': 'Recent Cases on Domicile',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13800551/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Liaqat Mir, Technical Lecturer & Consultant at Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13742229-isa-505-external-confirmations.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 5582044,
#    'guid': 'Buzzsprout-13742229',
#    'itunes_author_name': 'Liaqat Mir, Technical Lecturer & Consultant at Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '462',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '51',
#    'description': "<p>Liaqat Mir provides an overview of changes made in the revised ISA 505.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 11 Oct 2023 08:00:00 +0100',
#    'title': 'ISA 505 – External Confirmations',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13742229/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Helen Knight, Tax Content Writer and Presenter',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13641499-freeports-and-investment-zones.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 9429849,
#    'guid': 'Buzzsprout-13641499',
#    'itunes_author_name': 'Helen Knight, Tax Content Writer and Presenter',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '783',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '50',
#    'description': "<p>Helen Knight discusses the differences between Freeports and Investment zones.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 27 Sep 2023 08:00:00 +0100',
#    'title': 'Freeports and Investment Zones',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13641499/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Lee Eagling, A&A and Compliance Senior Manager',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13611241-proposed-updates-to-the-frc-ethical-standard.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 14474786,
#    'guid': 'Buzzsprout-13611241',
#    'itunes_author_name': 'Lee Eagling, A&A and Compliance Senior Manager',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1203',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '49',
#    'description': "<p>Lee Eagling runs through the updates proposed by the FRC to the Ethical Standard for auditors.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 20 Sep 2023 08:00:00 +0100',
#    'title': 'Proposed updates to the FRC Ethical Standard',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13611241/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mark Morton and Norman Allison',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13449078-tax-update.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 16385282,
#    'guid': 'Buzzsprout-13449078',
#    'itunes_author_name': 'Mark Morton and Norman Allison',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1363',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '48',
#    'description': "<p>Mark Morton and Norman Allison discuss the SDLT mixed-use, the death of MTD, HMRC service levels and the IR35 update.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Thu, 24 Aug 2023 08:00:00 +0100',
#    'title': 'Tax Update',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13449078/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Liaqat Mir, Technical Lecturer & Consultant at Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13389102-lgps-accounting-and-audit-issues.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 10496548,
#    'guid': 'Buzzsprout-13389102',
#    'itunes_author_name': 'Liaqat Mir, Technical Lecturer & Consultant at Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '872',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '47',
#    'description': "<p>Liaqat Mir, Mercia&apos;s Technical Lecturer &amp; Consultant takes a look at some of the issues around the LGPS surplus assets for the first time.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 16 Aug 2023 08:00:00 +0100',
#    'title': 'LGPS Accounting and Audit Issues',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13389102/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Pat Nown, Technical Lecturer & Consultant',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13335986-summer-tax-update.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 22840593,
#    'guid': 'Buzzsprout-13335986',
#    'itunes_author_name': 'Pat Nown, Technical Lecturer & Consultant',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1901',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '46',
#    'description': "<p>In this episode, Pat Nown discusses recent topical tax issues which include, the extraction of profits 2023/24, pensions tax relief and much more.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 02 Aug 2023 11:00:00 +0100',
#    'title': 'Summer Tax Update',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Lee Eagling, A&A and Compliance Senior Manager',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13217572-common-audit-report-issues.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 8071200,
#    'guid': 'Buzzsprout-13217572',
#    'itunes_author_name': 'Lee Eagling, A&A and Compliance Senior Manager',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '670',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '45',
#    'description': "<p>In this episode, Lee Eagling summarises the issues we frequently see in audit reports.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Mon, 17 Jul 2023 14:00:00 +0100',
#    'title': 'Common Audit Report Issues',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13217572/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Helen M. Knight',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13130853-return-of-associated-companies.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 7001274,
#    'guid': 'Buzzsprout-13130853',
#    'itunes_author_name': 'Helen M. Knight',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '581',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '44',
#    'description': "<p>Helen Knight takes a look at some of the issues around the reintroduction of the associated company rules and the potential impact.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Mon, 03 Jul 2023 11:00:00 +0100',
#    'title': 'Return of Associated Companies',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13130853/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/13065145-fair-values.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 5842021,
#    'guid': 'Buzzsprout-13065145',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '484',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '43',
#    'description': "<p>FRC’s Thematic Review of Fair Values\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 21 Jun 2023 07:00:00 +0100',
#    'title': 'Fair Values',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/13065145/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': ' Louise Conner, Management & Skills Trainer',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12951851-accountant-client-relationships-mitigating-risks-and-adding-value.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 4415592,
#    'guid': 'Buzzsprout-12951851',
#    'itunes_author_name': ' Louise Conner, Management & Skills Trainer',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '365',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '42',
#    'description': "<p>In today&apos;s fast-paced business environment, clients demand more than just expertise from their advisers. Louise Conner provides an overview of the results on the role of an accountant changing and how it&apos;s crucial for professionals to keep up with the changes to stay competitive.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Mon, 05 Jun 2023 08:00:00 +0100',
#    'title': 'Accountant-Client Relationships: Mitigating Risks and Adding Value',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Norman Allison, Technical Lecturer & Consultant',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12945085-overview-of-economic-crime-levy.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 3898305,
#    'guid': 'Buzzsprout-12945085',
#    'itunes_author_name': 'Norman Allison, Technical Lecturer & Consultant',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '322',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '40',
#    'description': "<p>In this episode, Norman Alison discusses who will oversee the Economic Crime Levy and what clients will it affect.\xa0\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Fri, 02 Jun 2023 08:00:00 +0100',
#    'title': 'Overview of Economic Crime Levy',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/12945085/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': ' Louise Conner, Management & Skills Trainer',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12945875-understanding-different-personalities-in-accounting.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 4647529,
#    'guid': 'Buzzsprout-12945875',
#    'itunes_author_name': ' Louise Conner, Management & Skills Trainer',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '384',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '41',
#    'description': "<p>Our personalities shape who we are and how we interact with the world around us. Speaker Louise Conner provides an overview of the different personality types and provides guidance on how to work with different personality types in the latest blog.\xa0<br/><br/>Our personalities shape who we are and how we interact with the world around us. Speaker Louise Conner provides an overview of the different personality types and provides guidance on how to work with different personality types in the latest blog.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Tue, 30 May 2023 16:00:00 +0100',
#    'title': 'Understanding Different Personalities in Accounting',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Louise Conner, Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12820709-building-resilience-in-accounting-strategies-for-coping-with-challenges-and-setbacks.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 4830318,
#    'guid': 'Buzzsprout-12820709',
#    'itunes_author_name': 'Louise Conner, Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '400',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '39',
#    'description': "<p>The world of accounting is no stranger to demanding workloads, high pressure, and unexpected setbacks. Speaker Louise Conner provides listeners with an overview of what resilience is and ways to learn this important skill.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Thu, 18 May 2023 08:00:00 +0100',
#    'title': 'Building Resilience in Accounting: Strategies for Coping with Challenges and Setbacks',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/12820709/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Liaqat Mir, Technical Lecturer & Consultant at Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12858896-new-icaew-cpd-policy.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 8909431,
#    'guid': 'Buzzsprout-12858896',
#    'itunes_author_name': 'Liaqat Mir, Technical Lecturer & Consultant at Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '740',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '39',
#    'description': "<p>Liaqat Mir looks at an overview of the changes to ICAEW’s CPD requirements applicable from 01 November 2023.<br/><br/>Liaqat Mir is a technical lecturer and consultant at Mercia Group.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Tue, 16 May 2023 16:00:00 +0100',
#    'title': 'New ICAEW CPD Policy',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Louise Conner, Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12813451-imposter-syndrome-in-accountants-understanding-overcoming-and-thriving.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 5414287,
#    'guid': 'Buzzsprout-12813451',
#    'itunes_author_name': 'Louise Conner, Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '448',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '38',
#    'description': "<p>Mercia speaker, Louise Conner provides an overview of what it means to have imposter syndrome as an accountant.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 10 May 2023 08:00:00 +0100',
#    'title': 'Imposter Syndrome in Accountants: Understanding, Overcoming, and Thriving',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/12813451/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Helen M. Knight',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12789847-tax-administration-and-maintenance-day.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 10501803,
#    'guid': 'Buzzsprout-12789847',
#    'itunes_author_name': 'Helen M. Knight',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '872',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '37',
#    'description': "<p>Helen M. Knight takes a look at some of the consultations released on Tax Administration and Maintenance Day on 27 April 2023.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Mon, 08 May 2023 08:00:00 +0100',
#    'title': 'Tax Administration and Maintenance Day',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/12789847/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Phil Frost',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12695599-deferred-tax.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 10822107,
#    'guid': 'Buzzsprout-12695599',
#    'itunes_author_name': 'Phil Frost',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '899',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '36',
#    'description': "<p>Phil Frost looks at topical issues affecting deferred tax.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 26 Apr 2023 08:00:00 +0100',
#    'title': 'Deferred Tax',
#    'transcripts': [{'type': 'text/html',
#      'url': 'https://www.buzzsprout.com/593080/12695599/transcript'}],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Helen M. Knight',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12592411-changes-to-the-research-and-development-tax-regime.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 9253659,
#    'guid': 'Buzzsprout-12592411',
#    'itunes_author_name': 'Helen M. Knight',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '768',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '35',
#    'description': "<p>Helen M. Knight talks about an overview of changes to the R&amp;D tax relief schemes from April 2023.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Mon, 10 Apr 2023 08:00:00 +0100',
#    'title': 'Changes to the Research and Development Tax Regime',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Liaqat Mir',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12578560-understanding-the-new-requirements-for-isa-600.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 5402041,
#    'guid': 'Buzzsprout-12578560',
#    'itunes_author_name': 'Liaqat Mir',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '447',
#    'itunes_explicit': 'true',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '34',
#    'description': "<p>In this episode, Liaqat Mir will be discussing the changes and updates made to the International Standard on Auditing (ISA) 600, &quot;Special Considerations – Audits of Group Financial Statements (Including the Work of Component Auditors).\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Mon, 03 Apr 2023 17:00:00 +0100',
#    'title': 'Understanding the new requirements for ISA 600',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Norman Alison',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/12452868-analysing-the-2023-spring-budget-what-it-means-for-you.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 11423185,
#    'guid': 'Buzzsprout-12452868',
#    'itunes_author_name': 'Norman Alison',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '949',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '33',
# ...
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>In this episode, we discuss how to use content to promote and market your firm.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Tue, 14 Jul 2020 13:00:00 +0100',
#    'title': 'An introduction to content marketing',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/4410737-vat-changes-for-the-construction-industry.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 1220381,
#    'guid': 'Buzzsprout-4410737',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '99',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>The Government announced that due to the coronavirus, the changes will be delayed again until 1 March 2021.\xa0\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Thu, 02 Jul 2020 11:00:00 +0100',
#    'title': 'VAT changes for the construction industry',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/4129709-covid-19-and-professional-indemnity-insurance.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 13156920,
#    'guid': 'Buzzsprout-4129709',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '1094',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>We invite Johnathon Filer from Brunel Professions to discuss COVID-19 and how this has effected PII’s.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Thu, 11 Jun 2020 11:00:00 +0100',
#    'title': 'COVID-19 and Professional Indemnity Insurance',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/3741188-covid-19-management-podcast-episode-3.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 33621769,
#    'guid': 'Buzzsprout-3741188',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '2799',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>Our latest episode focuses on wellbeing - including managing your own wellbeing, supporting your team and staying resilient.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 13 May 2020 16:00:00 +0100',
#    'title': 'COVID-19 Management Podcast - Episode 3',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/3446110-covid-19-management-podcast-episode-2.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 26182513,
#    'guid': 'Buzzsprout-3446110',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '2179',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>This episode focuses on supporting clients.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Tue, 21 Apr 2020 11:00:00 +0100',
#    'title': 'COVID-19 Management Podcast - Episode 2',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/3446080-covid-19-management-podcast-episode-1.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 29516574,
#    'guid': 'Buzzsprout-3446080',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '2457',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>This episode focuses on personal productivity and motivation.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Tue, 21 Apr 2020 10:00:00 +0100',
#    'title': 'COVID-19 Management Podcast - Episode 1',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/2985307-budget-2020-top-ten-tax-changes.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 3111413,
#    'guid': 'Buzzsprout-2985307',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '256',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '8',
#    'description': "<p>A top ten of tax changes to take away from today&apos;s Budget by Mark Morton.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 11 Mar 2020 21:00:00 +0000',
#    'title': 'Budget 2020 Top Ten Tax Changes',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/2868109-ir35-update-part-2.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 2586372,
#    'guid': 'Buzzsprout-2868109',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '213',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '7',
#    'description': "<p>A brief review of the Government&apos;s statement that IR35 changes will happen in April.\xa0</p><p>\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Fri, 28 Feb 2020 15:00:00 +0000',
#    'title': 'IR35 update - Part 2',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/2715610-ir35-update.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 1552869,
#    'guid': 'Buzzsprout-2715610',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '127',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '6',
#    'description': "<p>This podcast covers the recent announcements made by HMRC in relation to the 2020 changes.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Tue, 11 Feb 2020 14:00:00 +0000',
#    'title': 'IR35 update',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/2616217-the-loan-charge.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 3848109,
#    'guid': 'Buzzsprout-2616217',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '318',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': None,
#    'description': "<p>This podcast considers the important changes made by the Government to the loan charge rules.</p><p><br/></p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Thu, 30 Jan 2020 13:00:00 +0000',
#    'title': 'The loan charge',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/2308040-schedule-36.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 3504859,
#    'guid': 'Buzzsprout-2308040',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '289',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '4',
#    'description': "<p>Mark Morton shares his thoughts on HMRC&apos;s information powers and how they should work.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 18 Dec 2019 12:00:00 +0000',
#    'title': 'Schedule 36',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/2022066-check-your-entrepreneur-s-relief-er-position.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 3053846,
#    'guid': 'Buzzsprout-2022066',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '252',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '3',
#    'description': "<p>An insight into legislative changes to the entrepreneurs relief rules and the increase in HMRC compliance and case law.</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Fri, 08 Nov 2019 11:00:00 +0000',
#    'title': 'Check your Entrepreneur’s Relief (ER) position',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None},
#   {'author': 'Mercia Group',
#    'comments': None,
#    'creative_commons': None,
#    'enclosure_url': 'https://www.buzzsprout.com/593080/1960630-email-marketing-best-practices.mp3',
#    'enclosure_type': 'audio/mpeg',
#    'enclosure_length': 8105374,
#    'guid': 'Buzzsprout-1960630',
#    'itunes_author_name': 'Mercia Group',
#    'itunes_block': False,
#    'itunes_closed_captioned': None,
#    'itunes_duration': '673',
#    'itunes_explicit': 'false',
#    'itune_image': None,
#    'itunes_order': None,
#    'itunes_subtitle': None,
#    'itunes_summary': None,
#    'itunes_episode': '2',
#    'description': "<p>Understand the basic principles of email marketing for accountants with our useful podcast. We explore the key areas that must be considered for any email marketing campaign, from your email subject, to the analytics of a campaign.\xa0</p><p>For more information on this topic and more, please visit <a href='http://www.mercia-group.com'>www.mercia-group.com</a> for further details.</p>",
#    'link': None,
#    'published_date': 'Wed, 30 Oct 2019 14:00:00 +0000',
#    'title': 'Email marketing best practices',
#    'transcripts': [],
#    'podcast_season': None,
#    'podcast_episode': None,
#    'podcast_chapters': None,
#    'podcast_person': None,
#    'podcast_locked': None,
#    'podcast_funding': None,
#    'podcast_location': None,
#    'podcast_soundbite': None}],
#  'itunes_author_name': 'Mercia Group',
#  'itunes_block': False,
#  'itunes_categories': ['Business',
#   'News',
#   'Business News',
#   'Business',
#   'Investing'],
#  'itunes_complete': None,
#  'itunes_explicit': 'false',
#  'itune_image': None,
#  'itunes_keywords': None,
#  'itunes_new_feed_url': None,
#  'language': 'en-gb',
#  'last_build_date': 'Thu, 18 Apr 2024 15:25:52 +0100',
#  'link': None,
#  'managing_editor': None,
#  'published_date': None,
#  'pubsubhubbub': None,
#  'owner_name': 'Mercia Group',
#  'owner_email': None,
#  'subtitle': None,
#  'title': 'Mercia Podcast',
#  'ttl': None,
#  'web_master': None}

# %%
# assign directory
directory = '../data'
 
# iterate over files in
# that directory
for filename in os.listdir(directory):
    file = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(file):
        with open(file, "r") as f:
            podcast = Podcast(f.read())
            _podcast = podcast.to_dict()
            _podcast["items"] = _podcast["items"][0]
            print(_podcast)
    with open(file, "r") as f:
        while True:
            line = f.readline()
            print(line, end="")
            if "</item>" in line:
                break

# %%
def set_itunes_keywords(self):
        """Parses itunes keywords and set value"""
        #try:
        keywords = self.soup.find('itunes:keywords').string
        #except AttributeError:
        keywords = None
        #try:
        self.itunes_keywords = [keyword.strip()
                                    for keyword in keywords.split(',')]
        self.itunes_keywords = list(set(self.itunes_keywords))
        #except AttributeError:
        self.itunes_keywords = []

# %%
podcast.to_dict()

# %%
podcast.soup()[0].find("itunes:keywords").string

# %%
_podcast = podcast.to_dict()
del _podcast["items"]
print(_podcast)

# %%
podcast.time_published

# %%
with open("../data/self-storage-university.rss", "r") as f:
    _file = f.read()
    podcast = Podcast(_file)

# %%
import json

# %%
ep = podcast.to_dict()["items"][0]
ep["published_date"] = parser.parse(ep["published_date"])

# %%
episode = Episode(**ep)

# %%
episode.json()
# Out:
# '{"episode_id":null,"feed_id":null,"author":"Frank Rolfe","comments":null,"creative_commons":null,"enclosure_url":"https://2.gum.fm/op3.dev/e/pdcn.co/e/pdst.fm/e/dts.podtrac.com/redirect.mp3/media.transistor.fm/9ff40192/21ece8a8.mp3","enclosure_type":"audio/mpeg","enclosure_length":9989261,"guid":"12b45b83-54e5-4996-8aa8-f3b64fa57025","itunes_author_name":"Frank Rolfe","itunes_block":false,"itunes_closed_captioned":null,"itunes_duration":415,"itunes_explicit":false,"itune_image":null,"itunes_order":null,"itunes_subtitle":null,"itunes_summary":"There are several ways to find a self-storage facility to buy. Two of the best are “cold-calling” and “direct mail” – but happens when you combine them together? In this Self-Storage University podcast we’re going to review the powerful force that can be created by combining the postal service and the telephone.","itunes_episode":97,"description":"There are several ways to find a self-storage facility to buy. Two of the best are “cold-calling” and “direct mail” – but happens when you combine them together? In this Self-Storage University podcast we’re going to review the powerful force that can be created by combining the postal service and the telephone.","link":"https://share.transistor.fm/s/9ff40192","published_date":"2024-04-12T02:00:00-06:00","title":"What Happens When You Combine Direct Mail And Cold Calling","podcast_transcripts":null,"podcast_season":null,"podcast_episode":97,"podcast_chapters":null,"podcast_person":null,"podcast_locked":null,"podcast_funding":null,"podcast_location":null,"podcast_soundbite":null}'

# %%
episode.dict()

# %%
ep
# Out:
# {'author': 'Frank Rolfe',
#  'comments': None,
#  'creative_commons': None,
#  'enclosure_url': 'https://2.gum.fm/op3.dev/e/pdcn.co/e/pdst.fm/e/dts.podtrac.com/redirect.mp3/media.transistor.fm/9ff40192/21ece8a8.mp3',
#  'enclosure_type': 'audio/mpeg',
#  'enclosure_length': 9989261,
#  'guid': '12b45b83-54e5-4996-8aa8-f3b64fa57025',
#  'itunes_author_name': 'Frank Rolfe',
#  'itunes_block': False,
#  'itunes_closed_captioned': None,
#  'itunes_duration': '415',
#  'itunes_explicit': 'no',
#  'itune_image': None,
#  'itunes_order': None,
#  'itunes_subtitle': None,
#  'itunes_summary': '\n        <p>There are several ways to find a self-storage facility to buy. Two of the best are “cold-calling” and “direct mail” – but happens when you combine them together? In this Self-Storage University podcast we’re going to review the powerful force that can be created by combining the postal service and the telephone.</p>\n      ',
#  'itunes_episode': '97',
#  'description': '\n        <p>There are several ways to find a self-storage facility to buy. Two of the best are “cold-calling” and “direct mail” – but happens when you combine them together? In this Self-Storage University podcast we’re going to review the powerful force that can be created by combining the postal service and the telephone.</p>\n      ',
#  'link': 'https://share.transistor.fm/s/9ff40192',
#  'published_date': datetime.datetime(2024, 4, 12, 2, 0, tzinfo=tzoffset(None, -21600)),
#  'title': 'What Happens When You Combine Direct Mail And Cold Calling',
#  'transcripts': [{'type': 'text/plain',
#    'url': 'https://share.transistor.fm/s/9ff40192/transcript.txt'}],
#  'podcast_season': None,
#  'podcast_episode': '97',
#  'podcast_chapters': None,
#  'podcast_person': None,
#  'podcast_locked': None,
#  'podcast_funding': None,
#  'podcast_location': None,
#  'podcast_soundbite': None}

# %%
podcast.items[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 podcast.items[1].to_json()
#
# AttributeError: 'Item' object has no attribute 'to_json'
